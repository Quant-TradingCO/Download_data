# %% [markdown]
# ![This is an image](Quant-Trading.jpg)

# %% [markdown]
# <font size="3">
# Please visit our website <a href="https://www.quant-trading.co" target="_blank">quant-trading.co</a> for more tools on quantitative finance and data science.
# </font>

# %%
# !pip install pandasdmx

# %% [markdown]
# ## **How to download data from the EUROSTAT database?**
#
#
# <font size="3"> Eurostat is the statistical office of the European Union. To download data from the EUROSTAT database you can use the python library pandaSDMX. pandaSDMX is an Apache 2.0-licensed Python library that implements SDMX 2.1, a format for exchange of statistical data and metadata used by national statistical agencies, central banks, and international organisations.<br><br>
#
# <font size="3">pandaSDMX can be used to:<br><br>
#
# <font size="3">*Explore the data available from over 20 data providers such as the World Bank, BIS, ILO, ECB, Eurostat, OECD, UNICEF and United Nations. <br><br>
#
# <font size="3">*Parse data and metadata in SDMX-ML (XML) or SDMX-JSON formats. <br><br>
#
# <font size="3">*Convert data and metadata into pandas objects, for use with the analysis, plotting, and other tools in the Python data science ecosystem. <br><br>
#
# <font size="3">…and much more.<br><br>
#
# <font size="3"> You can even use pandaSDMX to download data from the European Central Bank "ECB", The Bank for International Settlement "BIS" and some other organizations. At the end of this notebook we will show an exmaple on how to do that for the BIS data.

# %%
import warnings
warnings.filterwarnings('ignore')

import pandasdmx as pdmx
import datetime

# %% [markdown]
# ## **Initiate an instance of the specific database**
#
#
# <font size="3">
# In this example we show how to download data for the ESTAT database. Below is an example using the Request method from the pandasDMX library.

# %%
#Initialize with ESTAT data
estat = pdmx.Request("ESTAT")
estat
# Out:
# <class 'pandasdmx.api.Request'> instance, source:                ESTAT (Eurostat)

# %% [markdown]
# <font size="3">
# Then we need to use the method dataflow to get a flow message.

# %%
flow_msg = estat.dataflow()
flow_msg
# Out:
# <pandasdmx.StructureMessage>
#   <Header>
#     id: 'DF1706875049'
#     prepared: '2024-02-02T12:57:29.853000+01:00'
#     sender: <Agency ESTAT>
#     source:
#     test: False
#   response: <Response [200]>
#   DataflowDefinition (7666): MAR_GO_QM_MT MAR_GO_QM_NL MAR_GO_QM_NO MAR...
#   DataStructureDefinition (7216): MAR_GO_QM_MT MAR_GO_QM_NL MAR_GO_QM_N...

# %% [markdown]
# <font size="3">
# And then, using dataflow again we can check the different indicators contained in the database.

# %%
flow_msg.dataflow
# Out:
# {'MAR_GO_QM_MT': <DataflowDefinition ESTAT:MAR_GO_QM_MT(1.0): Gross weight of goods transported to/from main ports - Malta - quarterly data>,
#  'MAR_GO_QM_NL': <DataflowDefinition ESTAT:MAR_GO_QM_NL(1.0): Gross weight of goods transported to/from main ports - Netherlands - quarterly data>,
#  'MAR_GO_QM_NO': <DataflowDefinition ESTAT:MAR_GO_QM_NO(1.0): Gross weight of goods transported to/from main ports - Norway - quarterly data>,
#  'MAR_GO_QM_PL': <DataflowDefinition ESTAT:MAR_GO_QM_PL(1.0): Gross weight of goods transported to/from main ports - Poland - quarterly data>,
#  'MAR_GO_QM_PT': <DataflowDefinition ESTAT:MAR_GO_QM_PT(1.0): Gross weight of goods transported to/from main ports - Portugal - quarterly data>,
#  'MAR_GO_QM_RO': <DataflowDefinition ESTAT:MAR_GO_QM_RO(1.0): Gross weight of goods transported to/from main ports - Romania - quarterly data>,
#  'MAR_GO_QM_SE': <DataflowDefinition ESTAT:MAR_GO_QM_SE(1.0): Gross weight of goods transported to/from main ports - Sweden - quarterly data>,
#  'MAR_GO_QM_SI': <DataflowDefinition ESTAT:MAR_GO_QM_SI(1.0): Gross weight of goods transported to/from main ports - Slovenia - quarterly data>,
#  'MAR_GO_QM_TR': <DataflowDefinition ESTAT:MAR_GO_QM_TR(1.0): Gross weight of goods transported to/from main ports - Türkiye - quarterly data>,
#  'MAR_GO_QM_UK': <DataflowDefinition ESTAT:MAR_GO_QM_UK(1.0): Gross weight of goods transported to/from main ports - United Kingdom - quarterly data>,
#  'MAR_MG_AA_CWH': <DataflowDefinition ESTAT:MAR_MG_AA_CWH(1.0): Country level - gross weight of goods handled in all ports>,
#  'MAR_MG_AA_CWHD': <DataflowDefinition ESTAT:MAR_MG_AA_CWHD(1.0): Country level - gross weight of goods handled in all ports, by direction>,
#  'MAR_MG_AA_PWHD': <DataflowDefinition ESTAT:MAR_MG_AA_PWHD(1.0): Gross weight of goods handled in the top 20 EU ports by direction>,
#  'MAR_MG_AM_CVH': <DataflowDefinition ESTAT:MAR_MG_AM_CVH(1.0): Country level - volume (in TEUs) of containers handled in main ports, by loading status>,
#  'MAR_MG_AM_CWHC': <DataflowDefinition ESTAT:MAR_MG_AM_CWHC(1.0): Country level - gross weight of goods handled in main ports, by type of cargo>,
#  'MAR_MG_AM_CWHG': <DataflowDefinition ESTAT:MAR_MG_AM_CWHG(1.0): Country level - Gross weight of goods handled in main ports, by type of goods>,
#  'MAR_MG_AM_CWT': <DataflowDefinition ESTAT:MAR_MG_AM_CWT(1.0): Country level - gross weight of goods transported to/from main ports>,
#  'MAR_MG_AM_CWTT': <DataflowDefinition ESTAT:MAR_MG_AM_CWTT(1.0): Country level - gross weight of goods transported to/from main ports, by type of traffic>,
#  'MAR_MG_AM_PVH': <DataflowDefinition ESTAT:MAR_MG_AM_PVH(1.0): Volume of containers handled in the top 20 EU main ports by loading status>,
#  'MAR_MG_AM_PWHC': <DataflowDefinition ESTAT:MAR_MG_AM_PWHC(1.0): Gross weight of goods handled in the top 20 EU main ports by type of cargo>,
#  'MAR_MP_AA_CPH': <DataflowDefinition ESTAT:MAR_MP_AA_CPH(1.0): Country level - passengers embarked and disembarked in all ports>,
#  'MAR_MP_AA_CPHD': <DataflowDefinition ESTAT:MAR_MP_AA_CPHD(1.0): Country level - passengers embarked and disembarked in all ports, by direction>,
#  'MAR_MP_AA_PPHD': <DataflowDefinition ESTAT:MAR_MP_AA_PPHD(1.0): Passengers embarked and disembarked in the top 20 EU ports>,
#  'MAR_MP_AM_CFT': <DataflowDefinition ESTAT:MAR_MP_AM_CFT(1.0): Passengers (excluding cruise passengers) transported from/to the main ports>,
#  'MAR_MP_AM_CFTT': <DataflowDefinition ESTAT:MAR_MP_AM_CFTT(1.0): Passengers (excluding cruise passengers) transported from/to the main ports by transport coverage>,
#  'MAR_MT_AM_CSVI': <DataflowDefinition ESTAT:MAR_MT_AM_CSVI(1.0): Country level - number and gross tonnage of vessels in the main ports (based on inwards declarations), by type of vessel>,
#  'MAR_PA_AA': <DataflowDefinition ESTAT:MAR_PA_AA(1.0): Passengers embarked and disembarked in all ports by direction - annual data>,
#  'MAR_PA_QM': <DataflowDefinition ESTAT:MAR_PA_QM(1.0): Passengers (excluding cruise passengers) transported from/to the main ports by direction and transport coverage - quarterly data>,
#  'MAR_PA_QM_BE': <DataflowDefinition ESTAT:MAR_PA_QM_BE(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Belgium - quarterly data>,
#  'MAR_PA_QM_DE': <DataflowDefinition ESTAT:MAR_PA_QM_DE(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Germany - quarterly data>,
#  'MAR_PA_QM_DK': <DataflowDefinition ESTAT:MAR_PA_QM_DK(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Denmark - quarterly data>,
#  'MAR_PA_QM_EE': <DataflowDefinition ESTAT:MAR_PA_QM_EE(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Estonia - quarterly data>,
#  'MAR_PA_QM_EL': <DataflowDefinition ESTAT:MAR_PA_QM_EL(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Greece - quarterly data>,
#  'MAR_PA_QM_ES': <DataflowDefinition ESTAT:MAR_PA_QM_ES(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Spain - quarterly data>,
#  'MAR_PA_QM_FI': <DataflowDefinition ESTAT:MAR_PA_QM_FI(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Finland - quarterly data>,
#  'MAR_PA_QM_FR': <DataflowDefinition ESTAT:MAR_PA_QM_FR(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - France - quarterly data>,
#  'MAR_PA_QM_HR': <DataflowDefinition ESTAT:MAR_PA_QM_HR(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Croatia - quarterly data>,
#  'MAR_PA_QM_IE': <DataflowDefinition ESTAT:MAR_PA_QM_IE(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Ireland - quarterly data>,
#  'MAR_PA_QM_IT': <DataflowDefinition ESTAT:MAR_PA_QM_IT(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Italy - quarterly data>,
#  'MAR_PA_QM_LT': <DataflowDefinition ESTAT:MAR_PA_QM_LT(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Lithuania - quarterly data>,
#  'MAR_PA_QM_LV': <DataflowDefinition ESTAT:MAR_PA_QM_LV(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Latvia- quarterly data>,
#  'MAR_PA_QM_ME': <DataflowDefinition ESTAT:MAR_PA_QM_ME(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Montenegro - quarterly data>,
#  'MAR_PA_QM_MT': <DataflowDefinition ESTAT:MAR_PA_QM_MT(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Malta - quarterly data>,
#  'MAR_PA_QM_NL': <DataflowDefinition ESTAT:MAR_PA_QM_NL(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Netherlands - quarterly data>,
#  'MAR_PA_QM_NO': <DataflowDefinition ESTAT:MAR_PA_QM_NO(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Norway - quarterly data>,
#  'MAR_PA_QM_PL': <DataflowDefinition ESTAT:MAR_PA_QM_PL(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Poland - quarterly data>,
#  'MAR_PA_QM_PT': <DataflowDefinition ESTAT:MAR_PA_QM_PT(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Portugal - quarterly data>,
#  'MAR_PA_QM_SE': <DataflowDefinition ESTAT:MAR_PA_QM_SE(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Sweden - quarterly data>,
#  'MAR_PA_QM_TR': <DataflowDefinition ESTAT:MAR_PA_QM_TR(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - Türkiye - quarterly data>,
#  'MAR_PA_QM_UK': <DataflowDefinition ESTAT:MAR_PA_QM_UK(1.0): Passengers (excluding cruise passengers) transported from/to the main ports - United Kingdom - quarterly data>,
#  'MAR_QG_QM_CWH': <DataflowDefinition ESTAT:MAR_QG_QM_CWH(1.0): Country level - gross weight of goods handled in main ports>,
#  'MAR_QG_QM_EWH': <DataflowDefinition ESTAT:MAR_QG_QM_EWH(1.0): EU level - top 20 extra-EU maritime trade flows by gross weight of goods handled in EU main ports>,
#  'MAR_QG_QM_EWHD': <DataflowDefinition ESTAT:MAR_QG_QM_EWHD(1.0): Eu level - gross weight of goods handled in main ports, by direction>,
#  'MAR_QG_QM_EWHG': <DataflowDefinition ESTAT:MAR_QG_QM_EWHG(1.0): Eu level - gross weight of goods handled in main ports, by various types of partner geographical areas>,
#  'MAR_QG_QM_EWHK': <DataflowDefinition ESTAT:MAR_QG_QM_EWHK(1.0): Eu level - gross weight of goods handled in main ports, by type of cargo>,
#  'MAR_QG_QM_EWHP': <DataflowDefinition ESTAT:MAR_QG_QM_EWHP(1.0): EU level - top 10 extra-EU partner countries by gross weight of goods handled in EU main ports>,
#  'MAR_QG_QM_EWHT': <DataflowDefinition ESTAT:MAR_QG_QM_EWHT(1.0): Eu level - gross weight of goods handled in main ports, by type of traffic>,
#  'MAR_QG_QM_PVH': <DataflowDefinition ESTAT:MAR_QG_QM_PVH(1.0): Top 5 ports for volume of containers - volume (in TEUs) of containers handled in each port>,
#  'MAR_QG_QM_PWH': <DataflowDefinition ESTAT:MAR_QG_QM_PWH(1.0): Top 5 ports - gross weight of goods handled in each port>,
#  'MAR_QG_QM_PWHB': <DataflowDefinition ESTAT:MAR_QG_QM_PWHB(1.0): Top 5 ports for dry bulk- gross weight of dry bulk goods handled in each port>,
#  'MAR_QG_QM_PWHC': <DataflowDefinition ESTAT:MAR_QG_QM_PWHC(1.0): Top 5 ports for containers - gross weight of goods in containers handled in each port>,
#  'MAR_QG_QM_PWHL': <DataflowDefinition ESTAT:MAR_QG_QM_PWHL(1.0): Top 5 ports for liquid bulk - gross weight of liquid bulk goods handled in each port>,
#  'MAR_QG_QM_PWHO': <DataflowDefinition ESTAT:MAR_QG_QM_PWHO(1.0): Top 5 ports for other cargo not elsewhere specified - gross weight of goods in other cargo not elsewhere specified handled in each port>,
#  'MAR_QG_QM_PWHR': <DataflowDefinition ESTAT:MAR_QG_QM_PWHR(1.0): Top 5 ports for Ro-ro units - gross weight of goods in Ro-Ro units handled in each port>,
#  'MAR_SG_AM_CV': <DataflowDefinition ESTAT:MAR_SG_AM_CV(1.0): Short sea shipping - country level - volume (in TEU's) of containers transported to/from main ports, by loading status>,
#  'MAR_SG_AM_CW': <DataflowDefinition ESTAT:MAR_SG_AM_CW(1.0): Short sea shipping - country level - gross weight of goods transported to/from main ports>,
#  'MAR_SG_AM_CWD': <DataflowDefinition ESTAT:MAR_SG_AM_CWD(1.0): Short sea shipping - country level - gross weight of goods transported to/from main ports, by direction>,
#  'MAR_SG_AM_CWK': <DataflowDefinition ESTAT:MAR_SG_AM_CWK(1.0): Short sea shipping - country level - gross weight of goods transported to/from main ports, by type of cargo>,
#  'MAR_SG_AM_CWS': <DataflowDefinition ESTAT:MAR_SG_AM_CWS(1.0): Short sea shipping - country level - gross weight of goods transported to/from main ports, by sea region of partner ports>,
#  'MAR_SG_AM_EWX': <DataflowDefinition ESTAT:MAR_SG_AM_EWX(1.0): Short sea shipping - EU level - gross weight of goods transported to/from main ports, by type of cargo for each sea region of partner ports>,
#  'MAR_SG_AM_PW': <DataflowDefinition ESTAT:MAR_SG_AM_PW(1.0): Gross weight of goods transported in short sea shipping from/to the top 20 EU ports>,
#  'MAR_SG_AM_PWB': <DataflowDefinition ESTAT:MAR_SG_AM_PWB(1.0): Gross weight of dry bulk goods transported in short sea shipping from/to the top 5 EU ports for dry bulk goods>,
#  'MAR_SG_AM_PWC': <DataflowDefinition ESTAT:MAR_SG_AM_PWC(1.0): Gross weight of goods in containers transported in short sea shipping from/to the top 5 EU ports for goods in containers>,
#  'MAR_SG_AM_PWL': <DataflowDefinition ESTAT:MAR_SG_AM_PWL(1.0): Gross weight of liquid bulk goods transported in short sea shipping from/to the top 5 EU ports for liquid bulk goods>,
#  'MAR_SG_AM_PWR': <DataflowDefinition ESTAT:MAR_SG_AM_PWR(1.0): Gross weight of goods in Ro-ro units transported in short sea shipping from/to the top 5 EU ports for goods in Ro-ro units>,
#  'MAR_TF_QM': <DataflowDefinition ESTAT:MAR_TF_QM(1.0): Vessels in main ports by type and size of vessels (based on inwards declarations) - quarterly data>,
#  'MAR_TP_GO': <DataflowDefinition ESTAT:MAR_TP_GO(1.0): Maritime goods transport performed in the Exclusive Economic Zone (EEZ) of the countries>,
#  'MAR_TP_PA': <DataflowDefinition ESTAT:MAR_TP_PA(1.0): Maritime passenger transport performed in the Exclusive Economic Zone (EEZ) of the countries>,
#  'MAR_TP_SSS': <DataflowDefinition ESTAT:MAR_TP_SSS(1.0): Maritime goods short-sea shipping performed in the Exclusive Economic Zone (EEZ) of the countries>,
#  'MED_AG1': <DataflowDefinition ESTAT:MED_AG1(1.0): Structural information>,
#  'MED_AG2': <DataflowDefinition ESTAT:MED_AG2(1.0): Crop production>,
#  'MED_AG31': <DataflowDefinition ESTAT:MED_AG31(1.0): Meat (total production)>,
#  'MED_AG32': <DataflowDefinition ESTAT:MED_AG32(1.0): Annual production and utilisation of milk on the farm>,
#  'MED_AG33': <DataflowDefinition ESTAT:MED_AG33(1.0): Livestock in number of heads>,
#  'MED_AG34': <DataflowDefinition ESTAT:MED_AG34(1.0): Poultry farming>,
#  'MED_AG41': <DataflowDefinition ESTAT:MED_AG41(1.0): Annual captures of fish - live weight in tonnes - by fishing areas>,
#  'MED_AG42': <DataflowDefinition ESTAT:MED_AG42(1.0): Annual aquaculture production - live weight in tonnes>,
#  'MED_AG50': <DataflowDefinition ESTAT:MED_AG50(1.0): Economic accounts for agriculture (EAA)>,
#  'MED_AG51': <DataflowDefinition ESTAT:MED_AG51(1.0): Price indices of agricultural input/output at nominal value (2000 = 100)>,
#  'MED_AIR1': <DataflowDefinition ESTAT:MED_AIR1(1.0): Air transport infrastructure: airports>,
#  'MED_AIR2': <DataflowDefinition ESTAT:MED_AIR2(1.0): Air transport infrastructure: length of paved runways>,
#  'MED_AIR3': <DataflowDefinition ESTAT:MED_AIR3(1.0): Air transport equipment: number of aircrafts>,
#  'MED_AIR4': <DataflowDefinition ESTAT:MED_AIR4(1.0): Air transport traffic: number of aircraft movements>,
#  'MED_AIR5': <DataflowDefinition ESTAT:MED_AIR5(1.0): Air transport traffic: freight and passengers>,
#  'MED_EC0': <DataflowDefinition ESTAT:MED_EC0(1.0): Additional indicators>,
#  'MED_EC1': <DataflowDefinition ESTAT:MED_EC1(1.0): Gross domestic product>,
#  'MED_EC2': <DataflowDefinition ESTAT:MED_EC2(1.0): Final consumption expenditure>,
#  'MED_EC3': <DataflowDefinition ESTAT:MED_EC3(1.0): Gross capital formation>,
#  'MED_EC4': <DataflowDefinition ESTAT:MED_EC4(1.0): International trade as a share of GDP>,
#  'MED_EC5': <DataflowDefinition ESTAT:MED_EC5(1.0): Gross value added>,
#  'MED_EC6': <DataflowDefinition ESTAT:MED_EC6(1.0): Balancing items>,
#  'MED_EC7': <DataflowDefinition ESTAT:MED_EC7(1.0): Debts>,
#  'MED_EC8': <DataflowDefinition ESTAT:MED_EC8(1.0): Prices (annual series)>,
#  'MED_EC9': <DataflowDefinition ESTAT:MED_EC9(1.0): Exchange rates>,
#  'MED_ECBP': <DataflowDefinition ESTAT:MED_ECBP(1.0): Balance of payments>,
#  'MED_ECET': <DataflowDefinition ESTAT:MED_ECET(1.0): International trade by SITC - 1 000 EUR>,
#  'MED_EG10': <DataflowDefinition ESTAT:MED_EG10(1.0): Primary energy production>,
#  'MED_EG20': <DataflowDefinition ESTAT:MED_EG20(1.0): Secondary energy production (transformation)>,
#  'MED_EG30': <DataflowDefinition ESTAT:MED_EG30(1.0): Energy consumption>,
#  'MED_EG_ALL': <DataflowDefinition ESTAT:MED_EG_ALL(1.0): Energy - historical data (2004-2007, former methodology and source)>,
#  'MED_EN1': <DataflowDefinition ESTAT:MED_EN1(1.0): GHG (Green House Gases) emissions>,
#  'MED_EN2': <DataflowDefinition ESTAT:MED_EN2(1.0): Air emissions per sector and per gas>,
#  'MED_EN21': <DataflowDefinition ESTAT:MED_EN21(1.0): Municipal waste>,
#  'MED_EN22': <DataflowDefinition ESTAT:MED_EN22(1.0): Generation of waste by sector>,
#  'MED_EN23': <DataflowDefinition ESTAT:MED_EN23(1.0): Composition of municipal waste>,
#  'MED_EN24': <DataflowDefinition ESTAT:MED_EN24(1.0): Treatment and disposal facilities>,
#  'MED_EN25': <DataflowDefinition ESTAT:MED_EN25(1.0): Management of waste>,
#  'MED_EN3': <DataflowDefinition ESTAT:MED_EN3(1.0): Local pollution>,
#  'MED_EN41': <DataflowDefinition ESTAT:MED_EN41(1.0): Renewable freshwater resources>,
#  'MED_EN42': <DataflowDefinition ESTAT:MED_EN42(1.0): Water use balance>,
#  'MED_EN43': <DataflowDefinition ESTAT:MED_EN43(1.0): Freshwater abstraction>,
#  'MED_EN44': <DataflowDefinition ESTAT:MED_EN44(1.0): Water supplied and used by economic sectors>,
#  'MED_EN46': <DataflowDefinition ESTAT:MED_EN46(1.0): Urban wastewater treatment>,
#  'MED_EN47': <DataflowDefinition ESTAT:MED_EN47(1.0): Population connected to Wastewater Treatment>,
#  'MED_EN51': <DataflowDefinition ESTAT:MED_EN51(1.0): Protected areas>,
#  'MED_EN52': <DataflowDefinition ESTAT:MED_EN52(1.0): Number of known species>,
#  'MED_EN53': <DataflowDefinition ESTAT:MED_EN53(1.0): Percentage of threatened species>,
#  'MED_EN61': <DataflowDefinition ESTAT:MED_EN61(1.0): Landuse>,
#  'MED_EN62': <DataflowDefinition ESTAT:MED_EN62(1.0): Forest and irrigated land>,
#  'MED_EN63': <DataflowDefinition ESTAT:MED_EN63(1.0): Erosion>,
#  'MED_MA1': <DataflowDefinition ESTAT:MED_MA1(1.0): Maritime transport infrastructure: ports>,
#  'MED_MA2': <DataflowDefinition ESTAT:MED_MA2(1.0): Maritime equipment - number of ships of 1 000 grt and over>,
#  'MED_MA3': <DataflowDefinition ESTAT:MED_MA3(1.0): Maritime equipment - number of ships of 300 grt and over>,
#  'MED_MA4': <DataflowDefinition ESTAT:MED_MA4(1.0): Maritime equipment - carrying capacity of ships of 1 000 grt and over>,
#  'MED_MA5': <DataflowDefinition ESTAT:MED_MA5(1.0): Maritime equipment - carrying capacity of ships of 300 grt and over>,
#  'MED_MA6': <DataflowDefinition ESTAT:MED_MA6(1.0): Maritime traffic: ship movements>,
#  'MED_MA7': <DataflowDefinition ESTAT:MED_MA7(1.0): Maritime traffic: passengers and freight>,
#  'MED_PS111': <DataflowDefinition ESTAT:MED_PS111(1.0): General indicators>,
#  'MED_PS112': <DataflowDefinition ESTAT:MED_PS112(1.0): Population on 1 January by sex and by age group>,
#  'MED_PS115': <DataflowDefinition ESTAT:MED_PS115(1.0): Average population (mid-year)>,
#  'MED_PS12': <DataflowDefinition ESTAT:MED_PS12(1.0): Demographic indicators>,
#  'MED_PS21': <DataflowDefinition ESTAT:MED_PS21(1.0): Literacy>,
#  'MED_PS22': <DataflowDefinition ESTAT:MED_PS22(1.0): General education>,
#  'MED_PS23': <DataflowDefinition ESTAT:MED_PS23(1.0): Higher education>,
#  'MED_PS24': <DataflowDefinition ESTAT:MED_PS24(1.0): Quality of education>,
#  'MED_PS25': <DataflowDefinition ESTAT:MED_PS25(1.0): Technical and vocational education training (TVET)>,
#  'MED_PS26': <DataflowDefinition ESTAT:MED_PS26(1.0): Public expenditure on education>,
#  'MED_PS311': <DataflowDefinition ESTAT:MED_PS311(1.0): Poverty lines>,
#  'MED_PS312': <DataflowDefinition ESTAT:MED_PS312(1.0): At-risk-of poverty rate>,
#  'MED_PS313': <DataflowDefinition ESTAT:MED_PS313(1.0): Poverty ratio>,
#  'MED_PS32': <DataflowDefinition ESTAT:MED_PS32(1.0): Access to basic services and housing>,
#  'MED_PS33': <DataflowDefinition ESTAT:MED_PS33(1.0): Communication>,
#  'MED_PS411': <DataflowDefinition ESTAT:MED_PS411(1.0): Employment>,
#  'MED_PS412': <DataflowDefinition ESTAT:MED_PS412(1.0): Economic activity>,
#  'MED_PS413': <DataflowDefinition ESTAT:MED_PS413(1.0): Employment characteristics>,
#  'MED_PS414': <DataflowDefinition ESTAT:MED_PS414(1.0): Employment and economic activity branches>,
#  'MED_PS421': <DataflowDefinition ESTAT:MED_PS421(1.0): Unemployment rate>,
#  'MED_PS422': <DataflowDefinition ESTAT:MED_PS422(1.0): Unemployment rate by education level>,
#  'MED_PS423': <DataflowDefinition ESTAT:MED_PS423(1.0): Proportion of persons living in jobless households>,
#  'MED_PS43': <DataflowDefinition ESTAT:MED_PS43(1.0): Wages>,
#  'MED_RA1': <DataflowDefinition ESTAT:MED_RA1(1.0): Rail infrastructure: length of network>,
#  'MED_RA2': <DataflowDefinition ESTAT:MED_RA2(1.0): Rail equipment: number of locomotives and passenger railways vehicles>,
#  'MED_RA3': <DataflowDefinition ESTAT:MED_RA3(1.0): Rail equipment: number and capacity of railways vehicles>,
#  'MED_RA4': <DataflowDefinition ESTAT:MED_RA4(1.0): Rail equipment: number and load capacity of goods transport wagons>,
#  'MED_RA5': <DataflowDefinition ESTAT:MED_RA5(1.0): Rail passenger and freight traffic>,
#  'MED_RD1': <DataflowDefinition ESTAT:MED_RD1(1.0): Road infrastructure: lenght of road network>,
#  'MED_RD2': <DataflowDefinition ESTAT:MED_RD2(1.0): Road equipment: number of road vehicles by categories>,
#  'MED_RD3': <DataflowDefinition ESTAT:MED_RD3(1.0): Road equipment: number of road vehicles by age>,
#  'MED_RD4': <DataflowDefinition ESTAT:MED_RD4(1.0): Road equipment: load capacity of lorries>,
#  'MED_RD5': <DataflowDefinition ESTAT:MED_RD5(1.0): Road equipment: new registrations by categories>,
#  'MED_RD6': <DataflowDefinition ESTAT:MED_RD6(1.0): Road traffic: road freight transport in volume>,
#  'MED_RD7': <DataflowDefinition ESTAT:MED_RD7(1.0): Road accidents: persons killed>,
#  'MED_TO11': <DataflowDefinition ESTAT:MED_TO11(1.0): Main flows>,
#  'MED_TO12': <DataflowDefinition ESTAT:MED_TO12(1.0): Arrivals by type of accommodation>,
#  'MED_TO13': <DataflowDefinition ESTAT:MED_TO13(1.0): Nights spent by type of accommodation>,
#  'MED_TO21': <DataflowDefinition ESTAT:MED_TO21(1.0): Accommodation establishments>,
#  'MED_TO22': <DataflowDefinition ESTAT:MED_TO22(1.0): Number of bed-places>,
#  'MET_10R_3EMP': <DataflowDefinition ESTAT:MET_10R_3EMP(1.0): Employment by NACE Rev. 2 activity and metropolitan typology>,
#  'MET_10R_3GDP': <DataflowDefinition ESTAT:MET_10R_3GDP(1.0): Gross domestic product (GDP) at current market prices by metropolitan regions>,
#  'MET_10R_3GVA': <DataflowDefinition ESTAT:MET_10R_3GVA(1.0): Gross value added at basic prices by metropolitan regions>,
#  'MET_10R_3PGDP': <DataflowDefinition ESTAT:MET_10R_3PGDP(1.0): Average annual population to calculate regional GDP data by metropolitan regions>,
#  'MET_BD_EN2': <DataflowDefinition ESTAT:MET_BD_EN2(1.0): Employer business demography by NACE Rev. 2activity and metropolitan regions>,
#  'MET_BD_ESIZE': <DataflowDefinition ESTAT:MET_BD_ESIZE(1.0): Employer business demography by size class and metropolitan regions>,
#  'MET_BD_HGN2': <DataflowDefinition ESTAT:MET_BD_HGN2(1.0): Business demography and high growth enterprise by NACE Rev. 2 activity and metropolitan regions>,
#  'MET_BD_SIZE': <DataflowDefinition ESTAT:MET_BD_SIZE(1.0): Business demography by size class and metropolitan regions>,
#  'MET_BIRTHS': <DataflowDefinition ESTAT:MET_BIRTHS(1.0): Live births (total) by metropolitan regions>,
#  'MET_CRIM_GEN': <DataflowDefinition ESTAT:MET_CRIM_GEN(1.0): Crimes recorded by the police by metropolitan regions>,
#  'MET_D3AREA': <DataflowDefinition ESTAT:MET_D3AREA(1.0): Area of the regions by metropolitan regions>,
#  'MET_D3DENS': <DataflowDefinition ESTAT:MET_D3DENS(1.0): Population density by metropolitan regions>,
#  'MET_DEATHS': <DataflowDefinition ESTAT:MET_DEATHS(1.0): Deaths (total) by metropolitan regions>,
#  'MET_EDAT_LFSE4': <DataflowDefinition ESTAT:MET_EDAT_LFSE4(1.0): Population aged 25-64 by educational attainment level, sex and metropolitan regions>,
#  'MET_GIND3': <DataflowDefinition ESTAT:MET_GIND3(1.0): Demographic balance and crude rates by metropolitan regions>,
#  'MET_IPR_DA': <DataflowDefinition ESTAT:MET_IPR_DA(1.0): Community design (CD) applications by metropolitan regions>,
#  'MET_IPR_DAGDP': <DataflowDefinition ESTAT:MET_IPR_DAGDP(1.0): Community design (CD) applications per billion GDP by metropolitan regions>,
#  'MET_IPR_DAPOP': <DataflowDefinition ESTAT:MET_IPR_DAPOP(1.0): Community design (CD) applications per million population by metropolitan regions>,
#  'MET_IPR_DFA': <DataflowDefinition ESTAT:MET_IPR_DFA(1.0): Community designs (CD) by metropolitan regions>,
#  'MET_IPR_DFAGDP': <DataflowDefinition ESTAT:MET_IPR_DFAGDP(1.0): Community designs (CD) per billion GDP by metropolitan regions>,
#  'MET_IPR_DFAPOP': <DataflowDefinition ESTAT:MET_IPR_DFAPOP(1.0): Community designs (CD) per million population by metropolitan regions>,
#  'MET_IPR_DR': <DataflowDefinition ESTAT:MET_IPR_DR(1.0): Registered Community designs (RCD) by metropolitan regions>,
#  'MET_IPR_TA': <DataflowDefinition ESTAT:MET_IPR_TA(1.0): European Union trade mark (EUTM) applications by metropolitan regions>,
#  'MET_IPR_TAGDP': <DataflowDefinition ESTAT:MET_IPR_TAGDP(1.0): European Union trade mark (EUTM) applications per billion GDP by metropolitan regions>,
#  'MET_IPR_TAPOP': <DataflowDefinition ESTAT:MET_IPR_TAPOP(1.0): European Union trade mark (EUTM) applications per million population by metropolitan regions>,
#  'MET_LFE3EMP': <DataflowDefinition ESTAT:MET_LFE3EMP(1.0): Employment by sex, age and metropolitan regions>,
#  'MET_LFE3EMPRT': <DataflowDefinition ESTAT:MET_LFE3EMPRT(1.0): Employment rates by sex and age and metropolitan regions>,
#  'MET_LFP3POP': <DataflowDefinition ESTAT:MET_LFP3POP(1.0): Economically active population by sex, age and metropolitan regions>,
#  'MET_LFSD3POP': <DataflowDefinition ESTAT:MET_LFSD3POP(1.0): Population by sex, age and metropolitan regions>,
#  'MET_LFU3PERS': <DataflowDefinition ESTAT:MET_LFU3PERS(1.0): Unemployment by sex, age and metropolitan regions>,
#  'MET_LFU3RT': <DataflowDefinition ESTAT:MET_LFU3RT(1.0): Unemployment rates by sex, age and metropolitan regions>,
#  'MET_PAT_EPIPC': <DataflowDefinition ESTAT:MET_PAT_EPIPC(1.0): Patent applications to the EPO by priority year, by international patent classification (IPC) sections, classes and metropolitan regions>,
#  'MET_PAT_EPTEC': <DataflowDefinition ESTAT:MET_PAT_EPTEC(1.0): High-tech patent applications to the EPO by priority year and metropolitan regions>,
#  'MET_PAT_EPTOT': <DataflowDefinition ESTAT:MET_PAT_EPTOT(1.0): Patent applications to the EPO by priority year and metropolitan regions>,
#  'MET_PJANAGGR3': <DataflowDefinition ESTAT:MET_PJANAGGR3(1.0): Population on 1 January by broad age group, sex and metropolitan regions>,
#  'MET_PJANGRP3': <DataflowDefinition ESTAT:MET_PJANGRP3(1.0): Population on 1 January by five year age group, sex and metropolitan regions>,
#  'MET_PROJ_19RANMIG': <DataflowDefinition ESTAT:MET_PROJ_19RANMIG(1.0): Assumptions for net migration by age, sex, type of projection and metropolitan regions>,
#  'MET_PROJ_19RDBI': <DataflowDefinition ESTAT:MET_PROJ_19RDBI(1.0): Demographic balances and indicators by type of projection and metropolitan regions>,
#  'MET_PROJ_19RDTH': <DataflowDefinition ESTAT:MET_PROJ_19RDTH(1.0): Projected deaths by age, sex, type of projection and metropolitan regions>,
#  'MET_PROJ_19RP': <DataflowDefinition ESTAT:MET_PROJ_19RP(1.0): Population on 1st January by age, sex, type of projection and metropolitan regions>,
#  'MET_ROAD_GONL': <DataflowDefinition ESTAT:MET_ROAD_GONL(1.0): National annual road freight transport by regions of loading, group of goods and metropolitan regions>,
#  'MET_ROAD_GONU': <DataflowDefinition ESTAT:MET_ROAD_GONU(1.0): National annual road freight transport by regions of unloading, group of goods and metropolitan regions>,
#  'MIGR_ACQ': <DataflowDefinition ESTAT:MIGR_ACQ(1.0): Acquisition of citizenship by age group, sex and former citizenship>,
#  'MIGR_ACQ1CTZ': <DataflowDefinition ESTAT:MIGR_ACQ1CTZ(1.0): Acquisition of citizenship by age group, sex and level of human development of former citizenship>,
#  'MIGR_ACQS': <DataflowDefinition ESTAT:MIGR_ACQS(1.0): Residents who acquired citizenship as a share of resident non-citizens by former citizenship and sex>,
#  'MIGR_ASYACCM': <DataflowDefinition ESTAT:MIGR_ASYACCM(1.0): Asylum applicants having had their applications processed under the accelerated procedure, by age, sex and citizenship - monthly data>,
#  'MIGR_ASYACCM$DV_961': <DataflowDefinition ESTAT:MIGR_ASYACCM$DV_961(1.0): Asylum applicants having had their applications processed under the accelerated procedure, by age, sex and citizenship - monthly data>,
#  'MIGR_ASYAPP1MP': <DataflowDefinition ESTAT:MIGR_ASYAPP1MP(1.0): First time asylum applicants - per million persons>,
#  'MIGR_ASYAPP1PC': <DataflowDefinition ESTAT:MIGR_ASYAPP1PC(1.0): First time asylum applicants - % of total asylum applicants>,
#  'MIGR_ASYAPP1UP': <DataflowDefinition ESTAT:MIGR_ASYAPP1UP(1.0): First time asylum applications of unaccompanied minors  - % of total first time asylum applications of minors>,
#  'MIGR_ASYAPPCTZA': <DataflowDefinition ESTAT:MIGR_ASYAPPCTZA(1.0): Asylum applicants by type of applicant, citizenship, age and sex - annual aggregated data>,
#  'MIGR_ASYAPPCTZA$DV_618': <DataflowDefinition ESTAT:MIGR_ASYAPPCTZA$DV_618(1.0): Asylum applicants by type of applicant, citizenship, age and sex - annual aggregated data>,
#  'MIGR_ASYAPPCTZM': <DataflowDefinition ESTAT:MIGR_ASYAPPCTZM(1.0): Asylum applicants by type of applicant, citizenship, age and sex - monthly data>,
#  'MIGR_ASYAPPCTZM$DV_721': <DataflowDefinition ESTAT:MIGR_ASYAPPCTZM$DV_721(1.0): Asylum applicants by type of applicant, citizenship, age and sex - monthly data>,
#  'MIGR_ASYCTZ': <DataflowDefinition ESTAT:MIGR_ASYCTZ(1.0): Asylum applicants by citizenship till 2007 - annual data>,
#  'MIGR_ASYCTZM': <DataflowDefinition ESTAT:MIGR_ASYCTZM(1.0): First time asylum applicants by citizenship till December 2007 - monthly data>,
#  'MIGR_ASYDCFINA': <DataflowDefinition ESTAT:MIGR_ASYDCFINA(1.0): Final decisions in appeal or review on applications by citizenship, age and sex - annual data>,
#  'MIGR_ASYDCFINA$DV_620': <DataflowDefinition ESTAT:MIGR_ASYDCFINA$DV_620(1.0): Final decisions in appeal or review on applications by citizenship, age and sex - annual data>,
#  'MIGR_ASYDCFSTA': <DataflowDefinition ESTAT:MIGR_ASYDCFSTA(1.0): First instance decisions on applications by citizenship, age and sex - annual aggregated data>,
#  'MIGR_ASYDCFSTA$DV_621': <DataflowDefinition ESTAT:MIGR_ASYDCFSTA$DV_621(1.0): First instance decisions on applications by citizenship, age and sex - annual aggregated data>,
#  'MIGR_ASYDCFSTQ': <DataflowDefinition ESTAT:MIGR_ASYDCFSTQ(1.0): First instance decisions on applications by citizenship, age and sex - quarterly data>,
#  'MIGR_ASYDCFSTQ$DV_722': <DataflowDefinition ESTAT:MIGR_ASYDCFSTQ$DV_722(1.0): First instance decisions on applications by citizenship, age and sex - quarterly data>,
#  'MIGR_ASYDCTZM': <DataflowDefinition ESTAT:MIGR_ASYDCTZM(1.0): Decisions on asylum applications by citizenship till December 2007 - monthly data>,
#  'MIGR_ASYDCTZY': <DataflowDefinition ESTAT:MIGR_ASYDCTZY(1.0): Decisions on asylum applications by citizenship till 2007 - annual data>,
#  'MIGR_ASYDEC1P': <DataflowDefinition ESTAT:MIGR_ASYDEC1P(1.0): Positive first instance decisions - per million persons>,
#  'MIGR_ASYDEC1PC': <DataflowDefinition ESTAT:MIGR_ASYDEC1PC(1.0): Asylum decisions at first instance by type of decision - % of total decisions at first instance>,
#  'MIGR_ASYDECFP': <DataflowDefinition ESTAT:MIGR_ASYDECFP(1.0): Asylum decisions at final instance by type of decision  - % of total decisions at final instance>,
#  'MIGR_ASYMRCA': <DataflowDefinition ESTAT:MIGR_ASYMRCA(1.0): Applicants having benefited from material reception conditions at the end of the reference year - annual data>,
#  'MIGR_ASYPENCTZM': <DataflowDefinition ESTAT:MIGR_ASYPENCTZM(1.0): Persons subject of asylum applications pending at the end of the month by citizenship, age and sex - monthly data>,
#  'MIGR_ASYPENCTZM$DV_723': <DataflowDefinition ESTAT:MIGR_ASYPENCTZM$DV_723(1.0): Persons subject of asylum applications pending at the end of the month by citizenship, age and sex - monthly data>,
#  'MIGR_ASYRELFA': <DataflowDefinition ESTAT:MIGR_ASYRELFA(1.0): Resettled persons by age, sex, citizenship and resettlement framework - annual data>,
#  'MIGR_ASYRESA': <DataflowDefinition ESTAT:MIGR_ASYRESA(1.0): Resettled persons by age, sex and citizenship - annual data>,
#  'MIGR_ASYRESA$DV_629': <DataflowDefinition ESTAT:MIGR_ASYRESA$DV_629(1.0): Resettled persons by age, sex and citizenship - annual data>,
#  'MIGR_ASYRESCRA': <DataflowDefinition ESTAT:MIGR_ASYRESCRA(1.0): Resettled persons by age, sex, citizenship and country of previous residence - annual data>,
#  'MIGR_ASYRESDA': <DataflowDefinition ESTAT:MIGR_ASYRESDA(1.0): Resettled persons by age, sex, citizenship and decision - annual data>,
#  'MIGR_ASYTPFA': <DataflowDefinition ESTAT:MIGR_ASYTPFA(1.0): Decisions granting temporary protection by citizenship, age and sex – annual data>,
#  'MIGR_ASYTPFA$DV_1381': <DataflowDefinition ESTAT:MIGR_ASYTPFA$DV_1381(1.0): Decisions granting temporary protection by citizenship, age and sex – annual data>,
#  'MIGR_ASYTPFM': <DataflowDefinition ESTAT:MIGR_ASYTPFM(1.0): Decisions granting temporary protection by citizenship, age and sex – monthly data>,
#  'MIGR_ASYTPFM$DV_1383': <DataflowDefinition ESTAT:MIGR_ASYTPFM$DV_1383(1.0): Decisions granting temporary protection by citizenship, age and sex – monthly data>,
#  'MIGR_ASYTPFPOP': <DataflowDefinition ESTAT:MIGR_ASYTPFPOP(1.0): Decisions granting temporary protection by citizenship - per thousand persons>,
#  'MIGR_ASYTPFQ': <DataflowDefinition ESTAT:MIGR_ASYTPFQ(1.0): Decisions granting temporary protection by citizenship, age and sex – quarterly data>,
#  'MIGR_ASYTPFQ$DV_1382': <DataflowDefinition ESTAT:MIGR_ASYTPFQ$DV_1382(1.0): Decisions granting temporary protection by citizenship, age and sex – quarterly data>,
#  'MIGR_ASYTPSM': <DataflowDefinition ESTAT:MIGR_ASYTPSM(1.0): Beneficiaries of temporary protection at the end of the month by citizenship, age and sex – monthly data>,
#  'MIGR_ASYTPSM$DV_1384': <DataflowDefinition ESTAT:MIGR_ASYTPSM$DV_1384(1.0): Beneficiaries of temporary protection at the end of the month by citizenship, age and sex – monthly data>,
#  'MIGR_ASYTPSPOP': <DataflowDefinition ESTAT:MIGR_ASYTPSPOP(1.0): Beneficiaries from temporary protection by citizenship - per thousand persons>,
#  'MIGR_ASYTPWQ': <DataflowDefinition ESTAT:MIGR_ASYTPWQ(1.0): Decisions withdrawing temporary protection by citizenship and reason – quarterly data>,
#  'MIGR_ASYUMACCM': <DataflowDefinition ESTAT:MIGR_ASYUMACCM(1.0): Unaccompanied minor asylum applicants having had their applications processed under the accelerated procedure, by age, sex and citizenship - monthly data>,
#  'MIGR_ASYUMACTA': <DataflowDefinition ESTAT:MIGR_ASYUMACTA(1.0): Unaccompanied minor asylum applicants by type of applicant, citizenship, age and sex - annual aggregated data>,
#  'MIGR_ASYUMACTM': <DataflowDefinition ESTAT:MIGR_ASYUMACTM(1.0): Unaccompanied minor asylum applicants by type of applicant, citizenship, age and sex - monthly data>,
#  'MIGR_ASYUMDCFA': <DataflowDefinition ESTAT:MIGR_ASYUMDCFA(1.0): First instance decisions on applications of unaccompanied minors by citizenship, age and sex - annual aggregated data>,
#  'MIGR_ASYUMDCFNA': <DataflowDefinition ESTAT:MIGR_ASYUMDCFNA(1.0): Final decisions in appeal or review on applications of unaccompanied minors by citizenship, age and sex - annual data>,
#  'MIGR_ASYUMDCFQ': <DataflowDefinition ESTAT:MIGR_ASYUMDCFQ(1.0): First instance decisions on applications of unaccompanied minors by citizenship, age and sex - quarterly data>,
#  'MIGR_ASYUMPCTM': <DataflowDefinition ESTAT:MIGR_ASYUMPCTM(1.0): Unaccompanied minors subject of asylum applications pending at the end of the month by citizenship, age and sex - monthly data>,
#  'MIGR_ASYUMRESA': <DataflowDefinition ESTAT:MIGR_ASYUMRESA(1.0): Resettled unaccompanied minors by age, sex and citizenship - annual data>,
#  'MIGR_ASYUMTPFA': <DataflowDefinition ESTAT:MIGR_ASYUMTPFA(1.0): Decisions granting temporary protection to unaccompanied minors by citizenship, age and sex – annual data>,
#  'MIGR_ASYUMTPFM': <DataflowDefinition ESTAT:MIGR_ASYUMTPFM(1.0): Decisions granting temporary protection to unaccompanied minors by citizenship, age and sex – monthly data>,
#  'MIGR_ASYUMTPFQ': <DataflowDefinition ESTAT:MIGR_ASYUMTPFQ(1.0): Decisions granting temporary protection to unaccompanied minors by citizenship, age and sex – quarterly data>,
#  'MIGR_ASYUMTPSM': <DataflowDefinition ESTAT:MIGR_ASYUMTPSM(1.0): Unaccompanied minors benefiting from temporary protection at the end of the month by citizenship, age and sex – monthly data>,
#  'MIGR_ASYUMTPWQ': <DataflowDefinition ESTAT:MIGR_ASYUMTPWQ(1.0): Decisions withdrawing temporary protection to unaccompanied minors by citizenship and reason – quarterly data>,
#  'MIGR_ASYUMWFNA': <DataflowDefinition ESTAT:MIGR_ASYUMWFNA(1.0): Decisions withdrawing status granted as final decision in appeal or review to unaccompanied minors by type of status withdrawn, citizenship and reason - annual data>,
#  'MIGR_ASYUMWIFA': <DataflowDefinition ESTAT:MIGR_ASYUMWIFA(1.0): Decisions withdrawing status granted at first instance decision to an unaccompanied minor by type of status withdrawn, citizenship and reason - annual aggregated data>,
#  'MIGR_ASYUMWIFQ': <DataflowDefinition ESTAT:MIGR_ASYUMWIFQ(1.0): Decisions withdrawing status granted at first instance decision to an unaccompanied minor by type of status withdrawn, citizenship and reason - quarterly data>,
#  'MIGR_ASYUMWITA': <DataflowDefinition ESTAT:MIGR_ASYUMWITA(1.0): Asylum applications of unaccompanied minors withdrawn by citizenship, age, sex and type of withdrawal - annual aggregated data>,
#  'MIGR_ASYUMWITM': <DataflowDefinition ESTAT:MIGR_ASYUMWITM(1.0): Asylum applications of unaccompanied minors withdrawn by citizenship, age, sex and type of withdrawal - monthly data>,
#  'MIGR_ASYUNAA': <DataflowDefinition ESTAT:MIGR_ASYUNAA(1.0): Asylum applicants considered to be unaccompanied minors by citizenship, age and sex - annual data>,
#  'MIGR_ASYWITFINA': <DataflowDefinition ESTAT:MIGR_ASYWITFINA(1.0): Decisions withdrawing status granted as final decision in appeal or review by type of status withdrawn - annual data>,
#  'MIGR_ASYWITFSTA': <DataflowDefinition ESTAT:MIGR_ASYWITFSTA(1.0): Decisions withdrawing status granted at first instance decision by type of status withdrawn, citizenship and reason - annual aggregated data>,
#  'MIGR_ASYWITFSTQ': <DataflowDefinition ESTAT:MIGR_ASYWITFSTQ(1.0): Decisions withdrawing status granted at first instance decision by type of status withdrawn, citizenship and reason- quarterly data>,
#  'MIGR_ASYWITHA': <DataflowDefinition ESTAT:MIGR_ASYWITHA(1.0): Asylum applications withdrawn by citizenship, age, sex and type of withdrawal - annual aggregated data>,
#  'MIGR_ASYWITHA$DV_1021': <DataflowDefinition ESTAT:MIGR_ASYWITHA$DV_1021(1.0): Asylum applications withdrawn by citizenship, age, sex and type of withdrawal - annual aggregated data>,
#  'MIGR_ASYWITHM': <DataflowDefinition ESTAT:MIGR_ASYWITHM(1.0): Asylum applications withdrawn by citizenship, age, sex and type of withdrawal - monthly data>,
#  'MIGR_ASYWITHM$DV_941': <DataflowDefinition ESTAT:MIGR_ASYWITHM$DV_941(1.0): Asylum applications withdrawn by citizenship, age, sex and type of withdrawal - monthly data>,
#  'MIGR_DUBDEDACI': <DataflowDefinition ESTAT:MIGR_DUBDEDACI(1.0): Decisions on incoming 'Dublin' requests based on EURODAC by submitting country (PARTNER), type of request, sex and type of applicant>,
#  'MIGR_DUBDEDACO': <DataflowDefinition ESTAT:MIGR_DUBDEDACO(1.0): Decisions on outgoing 'Dublin' requests based on EURODAC by receiving country (PARTNER), type of request, sex and type of applicant>,
#  'MIGR_DUBDI': <DataflowDefinition ESTAT:MIGR_DUBDI(1.0): Decisions on incoming 'Dublin' requests by submitting country (PARTNER), type of decision, type of request, legal provision, sex and type of applicant>,
#  'MIGR_DUBDO': <DataflowDefinition ESTAT:MIGR_DUBDO(1.0): Decisions on outgoing 'Dublin' requests by receiving country (PARTNER), type of decision, type of request, legal provision, sex and type of applicant>,
#  'MIGR_DUBDUNI': <DataflowDefinition ESTAT:MIGR_DUBDUNI(1.0): Unilateral 'Dublin' decisions by partner country, type of decision, sex and type of applicant>,
#  'MIGR_DUBREDACI': <DataflowDefinition ESTAT:MIGR_DUBREDACI(1.0): Incoming 'Dublin' requests based on EURODAC by submitting country (PARTNER), type of request, legal provision, sex and type of applicant>,
#  'MIGR_DUBREDACO': <DataflowDefinition ESTAT:MIGR_DUBREDACO(1.0): Outgoing 'Dublin' requests based on EURODAC by receiving country (PARTNER), type of request, legal provision, sex and type of applicant>,
#  'MIGR_DUBRESI': <DataflowDefinition ESTAT:MIGR_DUBRESI(1.0): Incoming responses to 'Dublin' requests for information by submitting country (PARTNER), legal provision, duration of response, sex and type of applicant>,
#  'MIGR_DUBRESO': <DataflowDefinition ESTAT:MIGR_DUBRESO(1.0): Outgoing responses to 'Dublin' requests for information by receiving country (PARTNER), legal provision, duration of response, sex and type of applicant>,
#  'MIGR_DUBRI': <DataflowDefinition ESTAT:MIGR_DUBRI(1.0): Incoming 'Dublin' requests by submitting country (PARTNER), type of request, legal provision, sex and type of applicant>,
#  'MIGR_DUBRINFI': <DataflowDefinition ESTAT:MIGR_DUBRINFI(1.0): Incoming 'Dublin' requests for information by submitting country (PARTNER), legal provision, sex and type of applicant>,
#  'MIGR_DUBRINFO': <DataflowDefinition ESTAT:MIGR_DUBRINFO(1.0): Outgoing 'Dublin' requests for information by receiving country (PARTNER), legal provision, sex and type of applicant>,
#  'MIGR_DUBRO': <DataflowDefinition ESTAT:MIGR_DUBRO(1.0): Outgoing 'Dublin' requests by receiving country (PARTNER), type of request, legal provision, sex and type of applicant>,
#  'MIGR_DUBRPENI': <DataflowDefinition ESTAT:MIGR_DUBRPENI(1.0): Pending 'Dublin' incoming requests by submitting country (PARTNER), type of request, sex and type of applicant>,
#  'MIGR_DUBRPENO': <DataflowDefinition ESTAT:MIGR_DUBRPENO(1.0): Pending 'Dublin' outgoing requests by receiving country (PARTNER), type of request, sex and type of applicant>,
#  'MIGR_DUBTI': <DataflowDefinition ESTAT:MIGR_DUBTI(1.0): Incoming 'Dublin' transfers by submitting country (PARTNER), legal provision, duration of transfer, sex and type of applicant>,
#  'MIGR_DUBTO': <DataflowDefinition ESTAT:MIGR_DUBTO(1.0): Outgoing 'Dublin' transfers by receiving country (PARTNER), legal provision, duration of transfer, sex and type of applicant>,
#  'MIGR_DUBTPENI': <DataflowDefinition ESTAT:MIGR_DUBTPENI(1.0): Pending incoming 'Dublin' transfers by submitting country (PARTNER), sex and type of applicant>,
#  'MIGR_DUBTPENO': <DataflowDefinition ESTAT:MIGR_DUBTPENO(1.0): Pending outgoing 'Dublin' transfers by receiving country (PARTNER), sex and type of applicant>,
#  'MIGR_EILPOP': <DataflowDefinition ESTAT:MIGR_EILPOP(1.0): Persons subject to immigration law enforcement - per thousand persons>,
#  'MIGR_EILRETPC': <DataflowDefinition ESTAT:MIGR_EILRETPC(1.0): Returns by type of return - % of total returns>,
#  'MIGR_EIORD': <DataflowDefinition ESTAT:MIGR_EIORD(1.0): Third country nationals ordered to leave - annual data (rounded)>,
#  'MIGR_EIORD$DV_1261': <DataflowDefinition ESTAT:MIGR_EIORD$DV_1261(1.0): Third country nationals ordered to leave - annual data (rounded)>,
#  'MIGR_EIORD1': <DataflowDefinition ESTAT:MIGR_EIORD1(1.0): Third country nationals ordered to leave by citizenship, age and sex - quarterly data (rounded)>,
#  'MIGR_EIORD2': <DataflowDefinition ESTAT:MIGR_EIORD2(1.0): Third-country unaccompanied minors ordered to leave, by citizenship, age and sex of the minor – quarterly data (rounded)>,
#  'MIGR_EIPRE': <DataflowDefinition ESTAT:MIGR_EIPRE(1.0): Third country nationals found to be illegally present - annual data (rounded)>,
#  'MIGR_EIPRE$DV_1221': <DataflowDefinition ESTAT:MIGR_EIPRE$DV_1221(1.0): Third country nationals found to be illegally present - annual data (rounded)>,
#  'MIGR_EIRFS': <DataflowDefinition ESTAT:MIGR_EIRFS(1.0): Third country nationals refused entry at the external borders - annual data (rounded)>,
#  'MIGR_EIRTN': <DataflowDefinition ESTAT:MIGR_EIRTN(1.0): Third country nationals returned following an order to leave - annual data (rounded)>,
#  'MIGR_EIRTN$DV_1241': <DataflowDefinition ESTAT:MIGR_EIRTN$DV_1241(1.0): Third country nationals returned following an order to leave - annual data (rounded)>,
#  'MIGR_EIRTN1': <DataflowDefinition ESTAT:MIGR_EIRTN1(1.0): Third-country nationals returned following an order to leave, by type of return, citizenship, country of destination, age and sex – quarterly data>,
#  'MIGR_EIRTN2': <DataflowDefinition ESTAT:MIGR_EIRTN2(1.0): Third-country unaccompanied minors returned following an order to leave, by type of return, citizenship, country of destination, age and sex of the minor – quarterly data (rounded)>,
#  'MIGR_EIRT_AGR': <DataflowDefinition ESTAT:MIGR_EIRT_AGR(1.0): Third-country nationals who have left the territory to a third country by type of agreement procedure and citizenship>,
#  'MIGR_EIRT_ASS': <DataflowDefinition ESTAT:MIGR_EIRT_ASS(1.0): Third-country nationals who have left the territory by type of assistance received and citizenship>,
#  'MIGR_EIRT_DES': <DataflowDefinition ESTAT:MIGR_EIRT_DES(1.0): Third-country nationals who have left the territory to a third country by destination country and citizenship>,
#  'MIGR_EIRT_VOL': <DataflowDefinition ESTAT:MIGR_EIRT_VOL(1.0): Third-country nationals who have left the territory by type of return and citizenship>,
#  'MIGR_EMI1CTZ': <DataflowDefinition ESTAT:MIGR_EMI1CTZ(1.0): Emigration by age group, sex and citizenship>,
#  'MIGR_EMI2': <DataflowDefinition ESTAT:MIGR_EMI2(1.0): Emigration by age and sex>,
#  'MIGR_EMI3NXT': <DataflowDefinition ESTAT:MIGR_EMI3NXT(1.0): Emigration by age group, sex and country of next usual residence>,
#  'MIGR_EMI4CTB': <DataflowDefinition ESTAT:MIGR_EMI4CTB(1.0): Emigration by age group, sex and country of birth>,
#  'MIGR_EMI5NXT': <DataflowDefinition ESTAT:MIGR_EMI5NXT(1.0): Emigration by group of country of next usual residence>,
#  'MIGR_EMICTZNXT': <DataflowDefinition ESTAT:MIGR_EMICTZNXT(1.0): Emigration by age group, sex, group of citizenship and group of country of next residence - ad hoc data collection (2015-2020)>,
#  'MIGR_IMM10CTB': <DataflowDefinition ESTAT:MIGR_IMM10CTB(1.0): Immigration by age group, sex and level of human development of the country of birth>,
#  'MIGR_IMM11PRV': <DataflowDefinition ESTAT:MIGR_IMM11PRV(1.0): Immigration by age group, sex and level of human development of the country of previous residence>,
#  'MIGR_IMM12PRV': <DataflowDefinition ESTAT:MIGR_IMM12PRV(1.0): Immigration by broad group of country of previous residence>,
#  'MIGR_IMM1CTZ': <DataflowDefinition ESTAT:MIGR_IMM1CTZ(1.0): Immigration by age group, sex and citizenship>,
#  'MIGR_IMM2CTZ': <DataflowDefinition ESTAT:MIGR_IMM2CTZ(1.0): Immigration by age, sex and group of citizenship>,
#  'MIGR_IMM3CTB': <DataflowDefinition ESTAT:MIGR_IMM3CTB(1.0): Immigration by age group, sex and country of birth>,
#  'MIGR_IMM4CTB': <DataflowDefinition ESTAT:MIGR_IMM4CTB(1.0): Immigration by age, sex and group of country of birth>,
#  'MIGR_IMM5PRV': <DataflowDefinition ESTAT:MIGR_IMM5PRV(1.0): Immigration by age group, sex and country of previous residence>,
#  'MIGR_IMM6CTZ': <DataflowDefinition ESTAT:MIGR_IMM6CTZ(1.0): Immigration by sex, citizenship and group of country of birth>,
#  'MIGR_IMM7CTB': <DataflowDefinition ESTAT:MIGR_IMM7CTB(1.0): Immigration by sex, country of birth and group of citizenship>,
#  'MIGR_IMM8': <DataflowDefinition ESTAT:MIGR_IMM8(1.0): Immigration by age and sex>,
#  'MIGR_IMM9CTZ': <DataflowDefinition ESTAT:MIGR_IMM9CTZ(1.0): Immigration by age group, sex and level of human development of the country of citizenship>,
#  'MIGR_IMMCTZPRV': <DataflowDefinition ESTAT:MIGR_IMMCTZPRV(1.0): Immigration by age group, sex, group of citizenship and group of country of previous residence - ad hoc data collection (2015-2020)>,
#  'MIGR_LCT': <DataflowDefinition ESTAT:MIGR_LCT(1.0): Loss of citizenship by sex and new citizenship>,
#  'MIGR_NETMIGR': <DataflowDefinition ESTAT:MIGR_NETMIGR(1.0): Net migration by age and sex>,
#  'MIGR_POP1CTZ': <DataflowDefinition ESTAT:MIGR_POP1CTZ(1.0): Population on 1 January by age group, sex and citizenship>,
#  'MIGR_POP1CTZ$DV_1764': <DataflowDefinition ESTAT:MIGR_POP1CTZ$DV_1764(1.0): Population on 1 January by age group, sex and citizenship>,
#  'MIGR_POP2CTZ': <DataflowDefinition ESTAT:MIGR_POP2CTZ(1.0): Population on 1 January by age, sex and broad group of citizenship>,
# ...
#  'RAIL_GO_TYPEALL': <DataflowDefinition ESTAT:RAIL_GO_TYPEALL(1.0): Goods transported by type of transport (2004-2016)>,
#  'EDAT_LFSE_28$DV_1849': <DataflowDefinition ESTAT:EDAT_LFSE_28$DV_1849(1.0): Young people neither in employment nor in education and training by sex, age and country of birth (NEET rates)>,
#  'RAIL_GO_TYPEPAS': <DataflowDefinition ESTAT:RAIL_GO_TYPEPAS(1.0): Goods transported by type of transport (detailed reporting only )>,
#  'RAIL_IF_ELECTRI': <DataflowDefinition ESTAT:RAIL_IF_ELECTRI(1.0): Length of electrified railway lines by type of current>,
#  'EDAT_LFSE_29': <DataflowDefinition ESTAT:EDAT_LFSE_29(1.0): Young people neither in employment nor in education and training by sex, age and degree of urbanisation (NEET rates)>,
#  'RAIL_IF_LINE_GA': <DataflowDefinition ESTAT:RAIL_IF_LINE_GA(1.0): Length of electrified and non-electrified railway lines by track gauge>,
#  'EDAT_LFSE_30': <DataflowDefinition ESTAT:EDAT_LFSE_30(1.0): Early leavers from education and training by sex and degree of urbanisation>,
#  'RAIL_IF_LINE_NA': <DataflowDefinition ESTAT:RAIL_IF_LINE_NA(1.0): Length of electric and non-electric railway lines by nature of transport>,
#  'EDAT_LFSE_31': <DataflowDefinition ESTAT:EDAT_LFSE_31(1.0): Employment rates of young people not in education and training by sex, educational attainment level, years since completion of highest level of education and citizenship>,
#  'RAIL_IF_LINE_SP': <DataflowDefinition ESTAT:RAIL_IF_LINE_SP(1.0): Length of railway lines by maximum permitted speed>,
#  'EDAT_LFSE_32': <DataflowDefinition ESTAT:EDAT_LFSE_32(1.0): Employment rates of young people not in education and training by sex, educational attainment level, years since completion of highest level of education and country of birth>,
#  'RAIL_IF_LINE_TR': <DataflowDefinition ESTAT:RAIL_IF_LINE_TR(1.0): Length of railway lines by number of tracks and electrification of lines>,
#  'RAIL_IF_LVLCROS': <DataflowDefinition ESTAT:RAIL_IF_LVLCROS(1.0): Level crossings by type (source: ERA)>,
#  'EDAT_LFSE_33': <DataflowDefinition ESTAT:EDAT_LFSE_33(1.0): Employment rates of young people not in education and training by sex, educational attainment level, years since completion of highest level of education and NUTS 2 regions>,
#  'RAIL_IF_TRACKS': <DataflowDefinition ESTAT:RAIL_IF_TRACKS(1.0): Length of railway tracks by electrification of tracks>,
#  'EDAT_LFSE_34': <DataflowDefinition ESTAT:EDAT_LFSE_34(1.0): Employment rates of young people not in education and training by sex, educational attainment level, years since completion of highest level of education and degree of urbanisation>,
#  'RAIL_IF_TRAFF': <DataflowDefinition ESTAT:RAIL_IF_TRAFF(1.0): Length of railway lines equipped with the railway traffic management system by type of signalling (source: ERA)>,
#  'EDAT_LFSE_35': <DataflowDefinition ESTAT:EDAT_LFSE_35(1.0): Young people neither in employment nor in education and training by sex, age, country of birth and degree of urbanisation (NEET rates)>,
#  'RAIL_PA_INTCMNG': <DataflowDefinition ESTAT:RAIL_PA_INTCMNG(1.0): International transport of passengers from the country of embarkation to the reporting country>,
#  'EDAT_LFSE_36': <DataflowDefinition ESTAT:EDAT_LFSE_36(1.0): Young people neither in employment nor in education and training by sex, age, citizenship and degree of urbanisation (NEET rates)>,
#  'RAIL_PA_INTGONG': <DataflowDefinition ESTAT:RAIL_PA_INTGONG(1.0): International transport of passengers from the reporting country to the country of disembarkation>,
#  'EDAT_LFSE_37': <DataflowDefinition ESTAT:EDAT_LFSE_37(1.0): Young people neither in employment nor in education and training by sex, age, country of birth and NUTS 2 regions (NEET rates)>,
#  'RAIL_PA_NBCAR': <DataflowDefinition ESTAT:RAIL_PA_NBCAR(1.0): Passenger cars in accompanied passenger car railway transport, by type of transport>,
#  'RAIL_PA_NBPASS': <DataflowDefinition ESTAT:RAIL_PA_NBPASS(1.0): Passengers in accompanied passenger car railway transport, by type of transport>,
#  'EDAT_LFSE_38': <DataflowDefinition ESTAT:EDAT_LFSE_38(1.0): Young people neither in employment nor in education and training by sex, age, citizenship and NUTS 2 regions (NEET rates)>,
#  'RAIL_PA_QUARTAL': <DataflowDefinition ESTAT:RAIL_PA_QUARTAL(1.0): Passengers transported (detailed reporting only) - (quarterly data)>,
#  'EDAT_LFSO_00T1': <DataflowDefinition ESTAT:EDAT_LFSO_00T1(1.0): Youth transitions from education to working life in Europe (in number of months)>,
#  'RAIL_PA_SPEED': <DataflowDefinition ESTAT:RAIL_PA_SPEED(1.0): Passengers transported by type of train speed>,
#  'RAIL_PA_TOTAL': <DataflowDefinition ESTAT:RAIL_PA_TOTAL(1.0): Passengers transported>,
#  'EDAT_LFSO_00T2': <DataflowDefinition ESTAT:EDAT_LFSO_00T2(1.0): Employed in service sector and occupational status of recent school-leavers>,
#  'RAIL_PA_TYPEPAS': <DataflowDefinition ESTAT:RAIL_PA_TYPEPAS(1.0): Passenger transport by type of transport (detailed reporting only)>,
#  'EDAT_LFSO_00T3': <DataflowDefinition ESTAT:EDAT_LFSO_00T3(1.0): Young people's social origin, educational attainment level and labour outcomes in Europe>,
#  'RAIL_TF_HAULMOV': <DataflowDefinition ESTAT:RAIL_TF_HAULMOV(1.0): Hauled railway vehicle traffic performance by train category and source of energy (gross tkm hauled)>,
#  'RAIL_TF_HAUSEAT': <DataflowDefinition ESTAT:RAIL_TF_HAUSEAT(1.0): Hauled passenger railway vehicle traffic performance by type of railway vehicle speed - seat km (until 2012)>,
#  'EDAT_LFSO_00T4': <DataflowDefinition ESTAT:EDAT_LFSO_00T4(1.0): Parents educational attainment level>,
#  'RAIL_TF_HAUTKMO': <DataflowDefinition ESTAT:RAIL_TF_HAUTKMO(1.0): Hauled vehicle traffic performance - tkm (until 2012)>,
#  'EDAT_LFSO_00T5': <DataflowDefinition ESTAT:EDAT_LFSO_00T5(1.0): Job mismatches and their labour market effects among school-leavers in Europe>,
#  'RAIL_TF_HAUTYPE': <DataflowDefinition ESTAT:RAIL_TF_HAUTYPE(1.0): Hauled railway vehicle traffic performance by type of railway vehicle (vehicle-km)>,
#  'EDAT_LFSO_09T1': <DataflowDefinition ESTAT:EDAT_LFSO_09T1(1.0): Average age when leaving formal education by sex and educational attainment level for persons who left within the last 3 or 5 years>,
#  'RAIL_TF_NS10_AT': <DataflowDefinition ESTAT:RAIL_TF_NS10_AT(1.0): Train traffic on the rail network - Austria (2010)>,
#  'EDAT_LFSO_09T2': <DataflowDefinition ESTAT:EDAT_LFSO_09T2(1.0): Average time between leaving formal education and starting the first job by age, sex and educational attainment level for persons who left within the last 3 or 5 years - (months)>,
#  'RAIL_TF_NS10_BE': <DataflowDefinition ESTAT:RAIL_TF_NS10_BE(1.0): Train traffic on the rail network - Belgium (2010)>,
#  'EDAT_LFSO_09T3': <DataflowDefinition ESTAT:EDAT_LFSO_09T3(1.0): Employment rates by age, sex, educational attainment level and number of years after leaving formal education>,
#  'RAIL_TF_NS10_BG': <DataflowDefinition ESTAT:RAIL_TF_NS10_BG(1.0): Train traffic on the rail network - Bulgaria (2010)>,
#  'EDAT_LFS_9901': <DataflowDefinition ESTAT:EDAT_LFS_9901(1.0): Population by educational attainment level, sex and age (1 000)>,
#  'EDAT_LFS_9902': <DataflowDefinition ESTAT:EDAT_LFS_9902(1.0): Population by educational attainment level, sex, age and labour status (1 000)>,
#  'RAIL_TF_NS10_CH': <DataflowDefinition ESTAT:RAIL_TF_NS10_CH(1.0): Train traffic on the rail network - Switzerland (2010)>,
#  'EDAT_LFS_9903': <DataflowDefinition ESTAT:EDAT_LFS_9903(1.0): Population by educational attainment level, sex and age (%)>,
#  'EDAT_LFS_9904': <DataflowDefinition ESTAT:EDAT_LFS_9904(1.0): Population by educational attainment level, sex, age and labour status (%)>,
#  'RAIL_TF_NS10_CZ': <DataflowDefinition ESTAT:RAIL_TF_NS10_CZ(1.0): Train traffic on the rail network - Czech Republic (2010)>,
#  'EDAT_LFS_9905': <DataflowDefinition ESTAT:EDAT_LFS_9905(1.0): Employees by educational attainment level, sex, age and occupation (%)>,
#  'RAIL_TF_NS10_DE': <DataflowDefinition ESTAT:RAIL_TF_NS10_DE(1.0): Train traffic on the rail network - Germany (2010)>,
#  'EDAT_LFS_9906': <DataflowDefinition ESTAT:EDAT_LFS_9906(1.0): Employees by educational attainment level, sex, age and employment contract (%)>,
#  'RAIL_TF_NS10_DK': <DataflowDefinition ESTAT:RAIL_TF_NS10_DK(1.0): Train traffic on the rail network - Denmark (2010)>,
#  'RAIL_TF_NS10_EE': <DataflowDefinition ESTAT:RAIL_TF_NS10_EE(1.0): Train traffic on the rail network - Estonia (2010)>,
#  'EDAT_LFS_9907': <DataflowDefinition ESTAT:EDAT_LFS_9907(1.0): Employees by educational attainment level, sex, age and full-time/part-time employment (%)>,
#  'RAIL_TF_NS10_EL': <DataflowDefinition ESTAT:RAIL_TF_NS10_EL(1.0): Train traffic on the rail network - Greece (2010)>,
#  'EDAT_LFS_9908': <DataflowDefinition ESTAT:EDAT_LFS_9908(1.0): Employees by educational attainment level, sex, age and size of the local unit (%)>,
#  'RAIL_TF_NS10_ES': <DataflowDefinition ESTAT:RAIL_TF_NS10_ES(1.0): Train traffic on the rail network - Spain (2010)>,
#  'EDAT_LFS_9909': <DataflowDefinition ESTAT:EDAT_LFS_9909(1.0): Employees by educational attainment level, sex, age and NACE Rev. 1.1 activity (%)>,
#  'RAIL_TF_NS10_FI': <DataflowDefinition ESTAT:RAIL_TF_NS10_FI(1.0): Train traffic on the rail network - Finland (2010)>,
#  'RAIL_TF_NS10_FR': <DataflowDefinition ESTAT:RAIL_TF_NS10_FR(1.0): Train traffic on the rail network - France (2010)>,
#  'EDAT_LFS_9910': <DataflowDefinition ESTAT:EDAT_LFS_9910(1.0): Employees by educational attainment level, sex, age and NACE Rev. 2 activity (%)>,
#  'RAIL_TF_NS10_HR': <DataflowDefinition ESTAT:RAIL_TF_NS10_HR(1.0): Train traffic on the rail network - Croatia (2010)>,
#  'EDAT_LFS_9911': <DataflowDefinition ESTAT:EDAT_LFS_9911(1.0): Population by educational attainment level, sex, age and citizenship (%)>,
#  'RAIL_TF_NS10_HU': <DataflowDefinition ESTAT:RAIL_TF_NS10_HU(1.0): Train traffic on the rail network - Hungary (2010)>,
#  'HLTH_EHIS_PA6I': <DataflowDefinition ESTAT:HLTH_EHIS_PA6I(1.0): Self-reported last colonoscopy by sex, age and income quintile>,
#  'EDAT_LFS_9911$DV_1702': <DataflowDefinition ESTAT:EDAT_LFS_9911$DV_1702(1.0): Population by educational attainment level, sex, age and citizenship (%)>,
#  'RAIL_TF_NS10_IE': <DataflowDefinition ESTAT:RAIL_TF_NS10_IE(1.0): Train traffic on the rail network - Ireland (2010)>,
#  'EDAT_LFS_9912': <DataflowDefinition ESTAT:EDAT_LFS_9912(1.0): Population by educational attainment level, sex, age and country of birth (%)>,
#  'RAIL_TF_NS10_IT': <DataflowDefinition ESTAT:RAIL_TF_NS10_IT(1.0): Train traffic on the rail network - Italia (2010)>,
#  'EDAT_LFS_9912$DV_1703': <DataflowDefinition ESTAT:EDAT_LFS_9912$DV_1703(1.0): Population by educational attainment level, sex, age and country of birth (%)>,
#  'RAIL_TF_NS10_LI': <DataflowDefinition ESTAT:RAIL_TF_NS10_LI(1.0): Train traffic on the rail network - Liechtenstein (2010)>,
#  'HLTH_EHIS_PA6U': <DataflowDefinition ESTAT:HLTH_EHIS_PA6U(1.0): Self-reported last colonoscopy by sex, age and degree of urbanisation>,
#  'EDAT_LFS_9913': <DataflowDefinition ESTAT:EDAT_LFS_9913(1.0): Population by educational attainment level, sex, age and degree of urbanisation (%)>,
#  'RAIL_TF_NS10_LT': <DataflowDefinition ESTAT:RAIL_TF_NS10_LT(1.0): Train traffic on the rail network - Lithuania (2010)>,
#  'EDAT_LFS_9914': <DataflowDefinition ESTAT:EDAT_LFS_9914(1.0): Population aged 15-34 by educational attainment level, sex, age and programme orientation (%)>,
#  'HLTH_EHIS_PA7E': <DataflowDefinition ESTAT:HLTH_EHIS_PA7E(1.0): Self-reported last breast examination by X-ray among women by age and educational attainment level>,
#  'RAIL_TF_NS10_LU': <DataflowDefinition ESTAT:RAIL_TF_NS10_LU(1.0): Train traffic on the rail network - Luxembourg (2010)>,
#  'RAIL_TF_NS10_LV': <DataflowDefinition ESTAT:RAIL_TF_NS10_LV(1.0): Train traffic on the rail network - Latvia (2010)>,
#  'HLTH_EHIS_PA7I': <DataflowDefinition ESTAT:HLTH_EHIS_PA7I(1.0): Self-reported last breast examination by X-ray among women by age and income quintile>,
#  'RAIL_TF_NS10_MK': <DataflowDefinition ESTAT:RAIL_TF_NS10_MK(1.0): Train traffic on the rail network - the Former Yugoslav Republic of Macedonia (2010)>,
#  'EDAT_LFS_9915': <DataflowDefinition ESTAT:EDAT_LFS_9915(1.0): Population by educational attainment level, sex, age, country of birth and degree of urbanisation (%)>,
#  'RAIL_TF_NS10_NL': <DataflowDefinition ESTAT:RAIL_TF_NS10_NL(1.0): Train traffic on the rail network - Netherlands (2010)>,
#  'HLTH_EHIS_PA7U': <DataflowDefinition ESTAT:HLTH_EHIS_PA7U(1.0): Self-reported last breast examination by X-ray among women by age and degree of urbanisation>,
#  'EDAT_LFS_9916': <DataflowDefinition ESTAT:EDAT_LFS_9916(1.0): Population by educational attainment level, sex, age, citizenship and degree of urbanisation (%)>,
#  'RAIL_TF_NS10_NO': <DataflowDefinition ESTAT:RAIL_TF_NS10_NO(1.0): Train traffic on the rail network - Norway (2010)>,
#  'HLTH_EHIS_PA8E': <DataflowDefinition ESTAT:HLTH_EHIS_PA8E(1.0): Self-reported last cervical smear test among women by age and educational attainment level>,
#  'RAIL_TF_NS10_PL': <DataflowDefinition ESTAT:RAIL_TF_NS10_PL(1.0): Train traffic on the rail network - Poland (2010)>,
#  'EDAT_LFS_9917': <DataflowDefinition ESTAT:EDAT_LFS_9917(1.0): Population by educational attainment level, sex, age, country of birth and NUTS 2 regions (%)>,
#  'RAIL_TF_NS10_PT': <DataflowDefinition ESTAT:RAIL_TF_NS10_PT(1.0): Train traffic on the rail network - Portugal (2010)>,
#  'HLTH_EHIS_PA8I': <DataflowDefinition ESTAT:HLTH_EHIS_PA8I(1.0): Self-reported last cervical smear test among women by age and income quintile>,
#  'EDAT_LFS_9918': <DataflowDefinition ESTAT:EDAT_LFS_9918(1.0): Population by educational attainment level, sex, age, citizenship and NUTS 2 regions (%)>,
#  'RAIL_TF_NS10_RO': <DataflowDefinition ESTAT:RAIL_TF_NS10_RO(1.0): Train traffic on the rail network - Romania (2010)>,
#  'HLTH_EHIS_PA8U': <DataflowDefinition ESTAT:HLTH_EHIS_PA8U(1.0): Self-reported last cervical smear test among women by age and degree of urbanisation>,
#  'EDAT_LFS_9919': <DataflowDefinition ESTAT:EDAT_LFS_9919(1.0): Population aged 20-34 with work experience while studying by sex, age, educational attainment level and years since completion of highest level of education>,
#  'RAIL_TF_NS10_SE': <DataflowDefinition ESTAT:RAIL_TF_NS10_SE(1.0): Train traffic on the rail network - Sweden (2010)>,
#  'HLTH_EHIS_PC1D': <DataflowDefinition ESTAT:HLTH_EHIS_PC1D(1.0): Difficulties in personal care activities by sex, age and level of disability (activity limitation)>,
#  'EDUC_ENRL1AD': <DataflowDefinition ESTAT:EDUC_ENRL1AD(1.0): Students by ISCED level, study intensity and sex>,
#  'RAIL_TF_NS10_SI': <DataflowDefinition ESTAT:RAIL_TF_NS10_SI(1.0): Train traffic on the rail network - Slovenia (2010)>,
#  'EDUC_ENRL1AT': <DataflowDefinition ESTAT:EDUC_ENRL1AT(1.0): Students by ISCED level, type of institution and study intensity>,
#  'HLTH_EHIS_PC1E': <DataflowDefinition ESTAT:HLTH_EHIS_PC1E(1.0): Difficulties in personal care activities by sex, age and educational attainment level>,
#  'RAIL_TF_NS10_SK': <DataflowDefinition ESTAT:RAIL_TF_NS10_SK(1.0): Train traffic on the rail network - Slovakia (2010)>,
#  'HLTH_EHIS_PC1HCS': <DataflowDefinition ESTAT:HLTH_EHIS_PC1HCS(1.0): Difficulties in personal care activities by sex, age and use of home care services>,
#  'EDUC_ENRL1TL': <DataflowDefinition ESTAT:EDUC_ENRL1TL(1.0): Students by ISCED level, age and sex>,
#  'RAIL_TF_NS10_TR': <DataflowDefinition ESTAT:RAIL_TF_NS10_TR(1.0): Train traffic on the rail network - Türkiye (2010)>,
#  'HLTH_EHIS_PC1I': <DataflowDefinition ESTAT:HLTH_EHIS_PC1I(1.0): Difficulties in personal care activities by sex, age and income quintile>,
#  'RAIL_TF_NS10_UK': <DataflowDefinition ESTAT:RAIL_TF_NS10_UK(1.0): Train traffic on the rail network - United Kingdom (2010)>,
#  'HLTH_EHIS_PC1U': <DataflowDefinition ESTAT:HLTH_EHIS_PC1U(1.0): Difficulties in personal care activities by sex, age and degree of urbanisation>,
#  ...}

# %% [markdown]
# <font size="3">
# It is probably easier to look at them from a pandas DataFrame as shown below:

# %%
dataflows = pdmx.to_pandas(flow_msg.dataflow)
dataflows
# Out:
# MAR_GO_QM_MT      Gross weight of goods transported to/from main...
# MAR_GO_QM_NL      Gross weight of goods transported to/from main...
# MAR_GO_QM_NO      Gross weight of goods transported to/from main...
# MAR_GO_QM_PL      Gross weight of goods transported to/from main...
# MAR_GO_QM_PT      Gross weight of goods transported to/from main...
#                                         ...
# HLTH_EHIS_PA2U    Self-reported screening of cardiovascular dise...
# HLTH_EHIS_PA5E    Self-reported last colorectal cancer screening...
# HLTH_EHIS_PA5I    Self-reported last colorectal cancer screening...
# HLTH_EHIS_PA5U    Self-reported last colorectal cancer screening...
# HLTH_EHIS_PA6E    Self-reported last colonoscopy by sex, age and...
# Length: 7666, dtype: object

# %% [markdown]
# <font size="3">
# As you can see there are a lot of indicators. We can check if there are any related with GDP growth. For that, we can use the function str.contains()

# %%
dataflows[dataflows.str.contains('gdp growth', case=False)].head(30)
# Out:
# TEC00115    Real GDP growth rate - volume
# dtype: object

# %% [markdown]
# <font size="3">
# Fortunately we found one indicator. Its name is "Real GDP growth rate - volume" and it has the identification code "TEC00115". We will use thise code to get the metadata related to it as shown below

# %%
metadata = estat.datastructure('TEC00115')
metadata
# Out:
# <pandasdmx.StructureMessage>
#   <Header>
#     id: 'DSD1706813388'
#     prepared: '2024-02-01T18:49:48.756000+00:00'
#     sender: <Agency ESTAT>
#     source:
#     test: False
#   response: <Response [200]>
#   Codelist (5): FREQ UNIT NA_ITEM GEO OBS_FLAG
#   ConceptScheme (1): TEC00115
#   DataStructureDefinition (1): TEC00115

# %% [markdown]
# <font size="3">
# From the metadata information we can look at the last row, which is called DataStructureDefinition. In this case is the same identification code we found before. We need to use that code to download the data. We can also use the metadata to get the information of the different fields in the database using the method codelist.

# %%
metadata.codelist
# Out:
# {'FREQ': <Codelist ESTAT:FREQ(3.2) (11 items): Time frequency>,
#  'UNIT': <Codelist ESTAT:UNIT(24.0) (714 items): Unit of measure>,
#  'NA_ITEM': <Codelist ESTAT:NA_ITEM(15.0) (665 items): National accounts indicator (ESA 2010)>,
#  'GEO': <Codelist ESTAT:GEO(17.0) (4089 items): Geopolitical entity (reporting)>,
#  'OBS_FLAG': <Codelist ESTAT:OBS_FLAG(1.33) (46 items): Observation status (Flag)>}

# %% [markdown]
# <font size="3">
# To download the information we can use the method "data". We can use the identification code we found before, and also a parameter to indicate which is the starting date

# %%
resp = estat.data(
    'TEC00115',    
    params={'startPeriod': '2000'},
    )

# %% [markdown]
# <font size="3">
# We can transform the information into a pandas DataFrame to have a better visualization

# %%
data = resp.to_pandas(datetime={'dim': 'TIME_PERIOD', 'freq': 'freq'})
data
# Out:
# geo                  AL          AT          BA          BE          BG  \
# na_item            B1GQ        B1GQ        B1GQ        B1GQ        B1GQ
# unit        CLV_PCH_PRE CLV_PCH_PRE CLV_PCH_PRE CLV_PCH_PRE CLV_PCH_PRE
# TIME_PERIOD
# 2012                1.4         0.7        -0.8         0.7         0.7
# 2013                1.0         0.0         2.3         0.5        -0.5
# 2014                1.8         0.7         1.2         1.6         0.9
# 2015                2.2         1.0         4.3         2.0         3.4
# 2016                3.3         2.0         3.2         1.3         3.0
# 2017                3.8         2.3         3.2         1.6         2.7
# 2018                4.0         2.4         3.8         1.8         2.7
# 2019                2.1         1.5         2.9         2.2         4.0
# 2020               -3.5        -6.6        -3.0        -5.3        -4.0
# 2021                NaN         4.2         7.4         6.9         7.7
# 2022                NaN         4.8         4.2         3.0         3.9
# 2023                NaN         NaN         NaN         NaN         NaN
#
# geo                  CH          CY          CZ          DE          DK  ...  \
# na_item            B1GQ        B1GQ        B1GQ        B1GQ        B1GQ  ...
# unit        CLV_PCH_PRE CLV_PCH_PRE CLV_PCH_PRE CLV_PCH_PRE CLV_PCH_PRE  ...
# TIME_PERIOD                                                              ...
# 2012                1.2        -3.4        -0.8         0.4         0.2  ...
# 2013                1.8        -6.6         0.0         0.4         0.9  ...
# 2014                2.3        -1.8         2.3         2.2         1.6  ...
# 2015                1.6         3.4         5.4         1.5         2.3  ...
# 2016                2.1         6.6         2.5         2.2         3.2  ...
# 2017                1.4         5.7         5.2         2.7         2.8  ...
# 2018                2.9         5.6         3.2         1.0         2.0  ...
# 2019                1.1         5.5         3.0         1.1         1.5  ...
# 2020               -2.1        -3.4        -5.5        -3.8        -2.4  ...
# 2021                5.4         9.9         3.6         3.2         6.8  ...
# 2022                2.6         5.1         2.4         1.8         2.7  ...
# 2023                NaN         NaN         NaN        -0.3         NaN  ...
#
# geo                      NO              PL              PT              RO  \
# na_item                B1GQ            B1GQ            B1GQ            B1GQ
# unit        CLV_PCH_PRE_HAB CLV_PCH_PRE_HAB CLV_PCH_PRE_HAB CLV_PCH_PRE_HAB
# TIME_PERIOD
# 2012                    1.4             1.5            -3.7             2.4
# 2013                   -0.2             0.9            -0.4             0.6
# 2014                    0.9             3.9             1.3             4.5
# 2015                    0.8             4.5             2.2             3.7
# 2016                    0.3             3.0             2.3             3.5
# 2017                    1.7             5.2             3.8             8.8
# 2018                    0.2             6.0             3.0             6.6
# 2019                    0.4             4.5             2.7             4.3
# 2020                   -1.8            -1.9            -8.4            -3.2
# 2021                    3.4             7.5             5.8             6.6
# 2022                    2.1             6.2             6.8             4.5
# 2023                    NaN             NaN             NaN             NaN
#
# geo                      RS              SE              SI              SK  \
# na_item                B1GQ            B1GQ            B1GQ            B1GQ
# unit        CLV_PCH_PRE_HAB CLV_PCH_PRE_HAB CLV_PCH_PRE_HAB CLV_PCH_PRE_HAB
# TIME_PERIOD
# 2012                   -0.2            -1.3            -2.8             1.2
# 2013                    3.4             0.3            -1.2             0.5
# 2014                   -1.1             1.6             2.7             2.6
# 2015                    2.3             3.4             2.1             5.1
# 2016                    3.9             0.8             3.1             1.8
# 2017                    2.6             1.2             4.8             2.8
# 2018                    5.1             0.8             4.1             3.9
# 2019                    4.9             1.0             2.7             2.4
# 2020                   -0.2            -2.9            -4.9            -3.5
# 2021                    8.7             5.5             8.0             5.2
# 2022                    5.2             2.2             2.4             0.9
# 2023                    NaN             NaN             NaN             NaN
#
# geo                      TR              UK
# na_item                B1GQ            B1GQ
# unit        CLV_PCH_PRE_HAB CLV_PCH_PRE_HAB
# TIME_PERIOD
# 2012                    3.5             0.8
# 2013                    7.1             1.5
# 2014                    3.5             2.1
# 2015                    4.7             1.6
# 2016                    1.9             0.9
# 2017                    6.1             1.1
# 2018                    1.6             0.6
# 2019                   -0.6             0.8
# 2020                    0.9             NaN
# 2021                   10.4             NaN
# 2022                    4.5             NaN
# 2023                    NaN             NaN
#
# [12 rows x 80 columns]

# %% [markdown]
# <font size="3">
# We can use the pandas xs method to return a specified section of the DataFrame. In this case we will filter by country, selecting only "DE" which stands for Germany

# %%
data.xs('DE',  axis=1, drop_level=False)
# Out:
# geo                  DE
# na_item            B1GQ
# unit        CLV_PCH_PRE CLV_PCH_PRE_HAB
# TIME_PERIOD
# 2012                0.4             0.2
# 2013                0.4             0.2
# 2014                2.2             1.8
# 2015                1.5             0.6
# 2016                2.2             1.4
# 2017                2.7             2.3
# 2018                1.0             0.7
# 2019                1.1             0.8
# 2020               -3.8            -3.9
# 2021                3.2             3.1
# 2022                1.8             1.1
# 2023               -0.3            -1.2

# %% [markdown]
# <font size="3">
# Here we got the historical dataseries of the GDP growth of Germany. However, we got 2 different dataseries. To explore what they are, we can apply a simple filter using the code below

# %%
df  = pdmx.to_pandas(metadata.codelist['UNIT'])
df.reset_index(inplace=True)
df1 = df.loc[(df['UNIT']=='CLV_PCH_PRE_HAB')|(df['UNIT']=='CLV_PCH_PRE')]
df1
# Out:
#                 UNIT                                               name parent
# 688      CLV_PCH_PRE  Chain linked volumes, percentage change on pre...   UNIT
# 691  CLV_PCH_PRE_HAB  Chain linked volumes, percentage change on pre...   UNIT

# %% [markdown]
# <font size="3">
# In the previous code we put the information into a pandas DataFrame first. Then we used the reset_index() method and finally used the "UNIT" column to apply a filter on it. The filter used the or operator | on both names we got. And to identifie the detail of those name we can do the following

# %%
print(df1.iloc[0]['name'])
print(df1.iloc[1]['name'])
# Out:
# Chain linked volumes, percentage change on previous period
# Chain linked volumes, percentage change on previous period, per capita

# %% [markdown]
# ## **Download information from the BIS database**
#
#
# <font size="3">
# To download information from the BIS database we can do pretty much the same. Follow the steps we showed before

# %%
bis = pdmx.Request("BIS")
flow_msg1 = bis.dataflow()
flow_msg1.dataflow
# Out:
# {'WS_CBPOL_D': <DataflowDefinition BIS:WS_CBPOL_D(1.0): Policy rates daily>,
#  'WS_CBPOL_M': <DataflowDefinition BIS:WS_CBPOL_M(1.0): Policy rates monthly>,
#  'WS_CBS_PUB': <DataflowDefinition BIS:WS_CBS_PUB(1.0): BIS consolidated banking>,
#  'WS_CPMI_CASHLESS': <DataflowDefinition BIS:WS_CPMI_CASHLESS(1.0): CPMI cashless payments (T5-6)>,
#  'WS_CPMI_CT1': <DataflowDefinition BIS:WS_CPMI_CT1(1.0): CPMI comparative tables type 1>,
#  'WS_CPMI_CT2': <DataflowDefinition BIS:WS_CPMI_CT2(1.0): CPMI comparative tables type 2>,
#  'WS_CPMI_DEVICES': <DataflowDefinition BIS:WS_CPMI_DEVICES(1.0): CPMI payment devices>,
#  'WS_CPMI_INSTITUTIONS': <DataflowDefinition BIS:WS_CPMI_INSTITUTIONS(1.0): CPMI institutions>,
#  'WS_CPMI_MACRO': <DataflowDefinition BIS:WS_CPMI_MACRO(1.0): CPMI Macro>,
#  'WS_CPMI_PARTICIPANTS': <DataflowDefinition BIS:WS_CPMI_PARTICIPANTS(1.0): CPMI participants>,
#  'WS_CPMI_SYSTEMS': <DataflowDefinition BIS:WS_CPMI_SYSTEMS(1.0): CPMI systems (T8-9-11-13-14-16-17-18-19)>,
#  'WS_CPP': <DataflowDefinition BIS:WS_CPP(1.0): Commercial property prices>,
#  'WS_CREDIT_GAP': <DataflowDefinition BIS:WS_CREDIT_GAP(1.0): BIS credit-to-GDP gaps>,
#  'WS_DEBT_SEC2_PUB': <DataflowDefinition BIS:WS_DEBT_SEC2_PUB(1.0): BIS debt securities>,
#  'WS_DER_OTC_TOV': <DataflowDefinition BIS:WS_DER_OTC_TOV(1.0): OTC derivatives turnover>,
#  'WS_DPP': <DataflowDefinition BIS:WS_DPP(1.0): Detailed residential property prices>,
#  'WS_DSR': <DataflowDefinition BIS:WS_DSR(1.0): BIS debt service ratio>,
#  'WS_EER_D': <DataflowDefinition BIS:WS_EER_D(1.0): BIS effective exchange rates daily>,
#  'WS_EER_M': <DataflowDefinition BIS:WS_EER_M(1.0): BIS effective exchange rates monthly>,
#  'WS_GLI': <DataflowDefinition BIS:WS_GLI(1.0): Global liquidity indicators>,
#  'WS_LBS_D_PUB': <DataflowDefinition BIS:WS_LBS_D_PUB(1.0): BIS locational banking>,
#  'WS_LONG_CPI': <DataflowDefinition BIS:WS_LONG_CPI(1.0): BIS long consumer prices>,
#  'WS_NA_SEC_DSS': <DataflowDefinition BIS:WS_NA_SEC_DSS(1.0): Debt securities statistics>,
#  'WS_OTC_DERIV2': <DataflowDefinition BIS:WS_OTC_DERIV2(1.0): OTC derivatives outstanding>,
#  'WS_SPP': <DataflowDefinition BIS:WS_SPP(1.0): BIS property prices: selected series>,
#  'WS_TC': <DataflowDefinition BIS:WS_TC(2.0): BIS long series on total credit>,
#  'WS_XRU': <DataflowDefinition BIS:WS_XRU(1.0): US dollar exchange rates, m,q,a>,
#  'WS_XRU_D': <DataflowDefinition BIS:WS_XRU_D(1.0): US dollar exchange rates, daily>,
#  'WS_XTD_DERIV': <DataflowDefinition BIS:WS_XTD_DERIV(1.0): Exchange traded derivatives>}

# %% [markdown]
# <font size="3">
# Here we selected the BIS effective exchange rate daily with identification code "WS_EER_D"

# %%
WS_EER_D_msg = bis.dataflow('WS_EER_D')
WS_EER_D_msg
# Out:
# <pandasdmx.StructureMessage>
#   <Header>
#     id: 'IDREFb132ffdd-9d8b-4aaf-b73b-f1d9457afa40'
#     prepared: '2024-02-02T12:02:30+00:00'
#     receiver: <Agency not_supplied>
#     sender: <Agency UNKNOWN>
#     source:
#     test: False
#   response: <Response [200]>
#   Categorisation (1): 2fa0f830-cd9c-632e-dffd-bceebf593440
#   CategoryScheme (1): BISWEB_CATSCHEME
#   Codelist (9): CL_AREA CL_BIS_UNIT CL_COLLECTION CL_CONF_STATUS CL_EER...
#   ConceptScheme (1): STANDALONE_CONCEPT_SCHEME
#   ContentConstraint (2): EER_D_NOM_BRO EER_D_NOM_NAR
#   DataflowDefinition (1): WS_EER_D
#   DataStructureDefinition (1): BIS_EER
#   AgencyScheme (1): AGENCIES

# %%
metadata2 = bis.datastructure('BIS_EER')

# %% [markdown]
# <font size="3">
# From the metadata information we will also get the dimensions. This is a little different than we did before, but we need that information for the BIS database, since the identification code refers to one of the components of the dimensions.

# %%
dsd = WS_EER_D_msg.dataflow.WS_EER_D.structure

# %% [markdown]
# <font size="3">
# Here we can see that one dimension component if REF_AREA. This probably is related to the country.

# %%
dsd.dimensions.components
# Out:
# [<Dimension FREQ>,
#  <Dimension EER_TYPE>,
#  <Dimension EER_BASKET>,
#  <Dimension REF_AREA>,
#  <TimeDimension TIME_PERIOD>]

# %% [markdown]
# <font size="3">
# Let's confirm if that is indeed the case

# %%
cl = dsd.dimensions.get('REF_AREA').local_representation.enumerated
pdmx.to_pandas(cl).reset_index().head(30)
# Out:
#    CL_AREA                                   name   parent
# 0       1X                                    ECB  CL_AREA
# 1       4T  Emerging market economies (aggregate)  CL_AREA
# 2       5A                All reporting economies  CL_AREA
# 3       5R                     Advanced economies  CL_AREA
# 4       AE                   United Arab Emirates  CL_AREA
# 5       AL                                Albania  CL_AREA
# 6       AR                              Argentina  CL_AREA
# 7       AT                                Austria  CL_AREA
# 8       AU                              Australia  CL_AREA
# 9       BA                   Bosnia & Herzegovina  CL_AREA
# 10      BE                                Belgium  CL_AREA
# 11     BE2                               Flanders  CL_AREA
# 12     BE3                               Wallonia  CL_AREA
# 13      BG                               Bulgaria  CL_AREA
# 14      BH                                Bahrain  CL_AREA
# 15      BM                                Bermuda  CL_AREA
# 16      BR                                 Brazil  CL_AREA
# 17      BS                                Bahamas  CL_AREA
# 18      BY                                Belarus  CL_AREA
# 19      CA                                 Canada  CL_AREA
# 20      CH                            Switzerland  CL_AREA
# 21      CL                                  Chile  CL_AREA
# 22      CN                                  China  CL_AREA
# 23      CO                               Colombia  CL_AREA
# 24      CS                    Serbia & Montenegro  CL_AREA
# 25      CY                                 Cyprus  CL_AREA
# 26      CZ                                Czechia  CL_AREA
# 27      DE                                Germany  CL_AREA
# 28    DEZ1                           West Germany  CL_AREA
# 29    DEZ2                           East Germany  CL_AREA

# %% [markdown]
# <font size="3">
# Now we are ready to download the information as we did before with the EUROSTAT database. Here we will show that we can download the information for specific values of the indicator. In this case we are only downloading information for 2 countries: Germany and Austria, "DE" and "AT".

# %%
key = dict(REF_AREA =['DE', 'AT'])
params = dict(startPeriod='2016')

bis = pdmx.Request('BIS')
data_msg2 = bis.data('WS_EER_D', key=key, params=params)
data = data_msg2.to_pandas(datetime={'dim': 'TIME_PERIOD', 'freq': 'FREQ'})
data
# Out:
# EER_TYPE          N
# EER_BASKET        N              B
# REF_AREA         DE     AT      DE      AT
# TIME_PERIOD
# 2016-01-01    97.71  98.90   94.39   96.72
# 2016-01-02      NaN    NaN     NaN     NaN
# 2016-01-03      NaN    NaN     NaN     NaN
# 2016-01-04    97.82  98.97   94.63   96.87
# 2016-01-05    97.38  98.73   94.06   96.51
# ...             ...    ...     ...     ...
# 2024-01-25   100.02  99.70  102.64  101.28
# 2024-01-26    99.92  99.64  102.53  101.21
# 2024-01-27      NaN    NaN     NaN     NaN
# 2024-01-28      NaN    NaN     NaN     NaN
# 2024-01-29    99.77  99.54  102.36  101.11
#
# [2951 rows x 4 columns]

# %% [markdown]
# If this content is helpful and you want to make a donation please click on the button
#
# [![paypal](https://www.paypalobjects.com/en_US/i/btn/btn_donateCC_LG.gif)](https://www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&hosted_button_id=29CVY97MEQ9BY)
