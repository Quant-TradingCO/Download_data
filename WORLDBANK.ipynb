# %% [markdown]
# ![This is an image](Quant-Trading.jpg)

# %% [markdown]
# <font size="3">
# Please visit our website <a href="https://www.quant-trading.co" target="_blank">quant-trading.co</a> for more tools on quantitative finance and data science.
# </font>

# %%
# !pip install pandas-datareader

# %% [markdown]
# # **WORLDBANK API**
#
# ## **¿What can you download using this API?**
#
# <font size="3"> The World Bank Indicators API provides access to nearly 16,000 time series indicators. Most of these indicators are available online through tools such as Databank and the Open Data website. The API provides programmatic access to this same data. Many data series date back over 50 years, and can be used to create interesting applications.<br><br>
#
# <font size="3"> The Indicators API provides access to over 45 databases, including:<br><br>
#
# World Development Indicators<br><br>
# International Debt Statistcs<br><br>
# Doing Business<br><br>
# Human Capital Index<br><br>
# Subnational Poverty<br><br>
#
# <font size="3">
# The pandas_datareader library allows you to fetch data from different sources, including Yahoo Finance for financial market data, World Bank for global development data, and St. Louis Fed for economic data. In this notebook, we’ll show how you can load data from WORLDBANK. Behind the scene, pandas_datareader pulls the data you want from the web in real time and assembles it into a pandas DataFrame. Because of the vastly different structure of web pages, each data source needs a different reader. Hence, pandas_datareader only supports reading from a limited number of sources, mostly related to financial and economic time series. Below you can find an example on how this works.

# %%
import warnings
warnings.filterwarnings('ignore')

from pandas_datareader import wb  #Pandas Datareader
import datetime

# %% [markdown]
# ## **Inspect all the countries available in the database**
#
# <font size="3"> One of the important features of the WorldBank database is that it contains a lot of indicators for different countries. You can download a DataFrame that contains most of the countries in the world with some classifications such as Income Level or Region. You can also get the iso code which is a identifier you can use to combine with other databases.
# <br><br>

# %%
countries = wb.get_countries()
countries
# Out:
#     iso3c iso2c                                               name  \
# 0     ABW    AW                                              Aruba
# 1     AFE    ZH                        Africa Eastern and Southern
# 2     AFG    AF                                        Afghanistan
# 3     AFR    A9                                             Africa
# 4     AFW    ZI                         Africa Western and Central
# ..    ...   ...                                                ...
# 291   XZN    A5  Sub-Saharan Africa excluding South Africa and ...
# 292   YEM    YE                                        Yemen, Rep.
# 293   ZAF    ZA                                       South Africa
# 294   ZMB    ZM                                             Zambia
# 295   ZWE    ZW                                           Zimbabwe
#
#                          region  \
# 0    Latin America & Caribbean
# 1                    Aggregates
# 2                    South Asia
# 3                    Aggregates
# 4                    Aggregates
# ..                          ...
# 291                  Aggregates
# 292  Middle East & North Africa
# 293         Sub-Saharan Africa
# 294         Sub-Saharan Africa
# 295         Sub-Saharan Africa
#
#                                            adminregion          incomeLevel  \
# 0                                                               High income
# 1                                                                Aggregates
# 2                                           South Asia           Low income
# 3                                                                Aggregates
# 4                                                                Aggregates
# ..                                                 ...                  ...
# 291                                                              Aggregates
# 292  Middle East & North Africa (excluding high inc...           Low income
# 293         Sub-Saharan Africa (excluding high income)  Upper middle income
# 294         Sub-Saharan Africa (excluding high income)  Lower middle income
# 295         Sub-Saharan Africa (excluding high income)  Lower middle income
#
#         lendingType capitalCity  longitude  latitude
# 0    Not classified  Oranjestad   -70.0167   12.5167
# 1        Aggregates                    NaN       NaN
# 2               IDA       Kabul    69.1761   34.5228
# 3        Aggregates                    NaN       NaN
# 4        Aggregates                    NaN       NaN
# ..              ...         ...        ...       ...
# 291      Aggregates                    NaN       NaN
# 292             IDA      Sana'a    44.2075   15.3520
# 293            IBRD    Pretoria    28.1871  -25.7460
# 294             IDA      Lusaka    28.2937  -15.3982
# 295           Blend      Harare    31.0672  -17.8312
#
# [296 rows x 10 columns]

# %% [markdown]
# ## **Select particular countries**
#
# <font size="3"> You can select particular rows in a DataFrame using the loc function. Below you can see an example where we select de countries DataFrame in the field region, and select the rows that are equal to 'Europe & Central Asia'. That script will select all the countries that belong to this region.
# <br><br>

# %%
europe_countries = countries.loc[countries['region']=='Europe & Central Asia']
europe_countries.head(10)
# Out:
#    iso3c iso2c                    name                 region  \
# 6    ALB    AL                 Albania  Europe & Central Asia
# 7    AND    AD                 Andorra  Europe & Central Asia
# 11   ARM    AM                 Armenia  Europe & Central Asia
# 15   AUT    AT                 Austria  Europe & Central Asia
# 16   AZE    AZ              Azerbaijan  Europe & Central Asia
# 20   BEL    BE                 Belgium  Europe & Central Asia
# 24   BGR    BG                Bulgaria  Europe & Central Asia
# 28   BIH    BA  Bosnia and Herzegovina  Europe & Central Asia
# 30   BLR    BY                 Belarus  Europe & Central Asia
# 47   CHE    CH             Switzerland  Europe & Central Asia
#
#                                       adminregion          incomeLevel  \
# 6   Europe & Central Asia (excluding high income)  Upper middle income
# 7                                                          High income
# 11  Europe & Central Asia (excluding high income)  Upper middle income
# 15                                                         High income
# 16  Europe & Central Asia (excluding high income)  Upper middle income
# 20                                                         High income
# 24  Europe & Central Asia (excluding high income)  Upper middle income
# 28  Europe & Central Asia (excluding high income)  Upper middle income
# 30  Europe & Central Asia (excluding high income)  Upper middle income
# 47                                                         High income
#
#        lendingType       capitalCity  longitude  latitude
# 6             IBRD            Tirane   19.81720   41.3317
# 7   Not classified  Andorra la Vella    1.52180   42.5075
# 11            IBRD           Yerevan   44.50900   40.1596
# 15  Not classified            Vienna   16.37980   48.2201
# 16            IBRD              Baku   49.89320   40.3834
# 20  Not classified          Brussels    4.36761   50.8371
# 24            IBRD             Sofia   23.32380   42.7105
# 28            IBRD          Sarajevo   18.42140   43.8607
# 30            IBRD             Minsk   27.57660   53.9678
# 47  Not classified              Bern    7.44821   46.9480

# %% [markdown]
# ## **Inspect all the indicators available in the database**
#
# <font size="3"> You can get all the indicators using the function get_indicators(). As you can see below, the list contains 24.114 different indicators.
# <br><br>

# %%
#Download information about all World Bank data series
indicators = wb.get_indicators()
indicators
# Out:
#                          id  \
# 0        1.0.HCount.1.90usd
# 1         1.0.HCount.2.5usd
# 2      1.0.HCount.Mid10to50
# 3           1.0.HCount.Ofcl
# 4       1.0.HCount.Poor4uds
# ...                     ...
# 24408               w_F_skl
# 24409               w_M_nsk
# 24410               w_M_skl
# 24411             wpremia_F
# 24412             wpremia_M
#
#                                                     name unit  \
# 0                        Poverty Headcount ($1.90 a day)
# 1                        Poverty Headcount ($2.50 a day)
# 2                  Middle Class ($10-50 a day) Headcount
# 3                Official Moderate Poverty Rate-National
# 4                           Poverty Headcount ($4 a day)
# ...                                                  ...  ...
# 24408     Annual wage for skilled female workers  in US$
# 24409     Annual wage for unskilled male workers  in US$
# 24410       Annual wage for skilled male workers  in US$
# 24411  Wage Premia for Females (the ratio of skilled ...
# 24412  Wage Premia for Males  (the ratio of skilled m...
#
#                                            source  \
# 0                                  LAC Equity Lab
# 1                                  LAC Equity Lab
# 2                                  LAC Equity Lab
# 3                                  LAC Equity Lab
# 4                                  LAC Equity Lab
# ...                                           ...
# 24408  Gender Disaggregated Labor Database (GDLD)
# 24409  Gender Disaggregated Labor Database (GDLD)
# 24410  Gender Disaggregated Labor Database (GDLD)
# 24411  Gender Disaggregated Labor Database (GDLD)
# 24412  Gender Disaggregated Labor Database (GDLD)
#
#                                               sourceNote  \
# 0      The poverty headcount index measures the propo...
# 1      The poverty headcount index measures the propo...
# 2      The poverty headcount index measures the propo...
# 3      The poverty headcount index measures the propo...
# 4      The poverty headcount index measures the propo...
# ...                                                  ...
# 24408
# 24409
# 24410
# 24411
# 24412
#
#                                       sourceOrganization    topics
# 0      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 1      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 2      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 3      b'LAC Equity Lab tabulations of data from Nati...  Poverty
# 4      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# ...                                                  ...       ...
# 24408                                                b''
# 24409                                                b''
# 24410                                                b''
# 24411                                                b''
# 24412                                                b''
#
# [24413 rows x 7 columns]

# %% [markdown]
# ## **Select specific indicators**
#
# <font size="3"> As we showed before, you can select particular rows in a DataFrame using the loc function. Instead of using the operator equal to, we will use the function str.contains . That functions allows us to look for a particular text and select all the rows that contain that text. In this case we are looking for all rows that contain the word 'Poverty" in the field name as shown below.
# <br><br>

# %%
poverty_indicators = indicators.loc[indicators['name'].str.contains('Poverty')]
poverty_indicators
# Out:
#                         id                                               name  \
# 0       1.0.HCount.1.90usd                    Poverty Headcount ($1.90 a day)
# 1        1.0.HCount.2.5usd                    Poverty Headcount ($2.50 a day)
# 3          1.0.HCount.Ofcl            Official Moderate Poverty Rate-National
# 4      1.0.HCount.Poor4uds                       Poverty Headcount ($4 a day)
# 6         1.0.PGap.1.90usd                          Poverty Gap ($1.90 a day)
# ...                    ...                                                ...
# 24364     per_si_ss_p0_urb  Poverty Headcount reduction (%) -  Other Socia...
# 24365  per_si_ss_p1_ep_tot  Poverty Gap reduction (%) -  Other Social Insu...
# 24366     per_si_ss_p1_rur  Poverty Gap reduction (%) -  Other Social Insu...
# 24367     per_si_ss_p1_tot  Poverty Gap reduction (%) -  Other Social Insu...
# 24368     per_si_ss_p1_urb  Poverty Gap reduction (%) -  Other Social Insu...
#
#       unit                                             source  \
# 0                                              LAC Equity Lab
# 1                                              LAC Equity Lab
# 3                                              LAC Equity Lab
# 4                                              LAC Equity Lab
# 6                                              LAC Equity Lab
# ...    ...                                                ...
# 24364       The Atlas of Social Protection: Indicators of ...
# 24365       The Atlas of Social Protection: Indicators of ...
# 24366       The Atlas of Social Protection: Indicators of ...
# 24367       The Atlas of Social Protection: Indicators of ...
# 24368       The Atlas of Social Protection: Indicators of ...
#
#                                               sourceNote  \
# 0      The poverty headcount index measures the propo...
# 1      The poverty headcount index measures the propo...
# 3      The poverty headcount index measures the propo...
# 4      The poverty headcount index measures the propo...
# 6      The poverty gap captures the mean aggregate in...
# ...                                                  ...
# 24364  Poverty headcount reduction due to Other Socia...
# 24365  Poverty gap reduction due to Other Social Insu...
# 24366  Poverty gap reduction due to Other Social Insu...
# 24367  Poverty gap reduction due to Other Social Insu...
# 24368  Poverty gap reduction due to Other Social Insu...
#
#                                       sourceOrganization  \
# 0      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# 1      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# 3      b'LAC Equity Lab tabulations of data from Nati...
# 4      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# 6      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# ...                                                  ...
# 24364                                          b'ASPIRE'
# 24365                                          b'ASPIRE'
# 24366                                          b'ASPIRE'
# 24367                                          b'ASPIRE'
# 24368                                          b'ASPIRE'
#
#                           topics
# 0                       Poverty
# 1                       Poverty
# 3                       Poverty
# 4                       Poverty
# 6                       Poverty
# ...                          ...
# 24364  Social Protection & Labor
# 24365  Social Protection & Labor
# 24366  Social Protection & Labor
# 24367  Social Protection & Labor
# 24368  Social Protection & Labor
#
# [203 rows x 7 columns]

# %% [markdown]
# ## **Search function**
#
# <font size="3"> You can use the function search to look for particular information on the database. You just need to write the words you are looking for, and the function will return all the rows that contain that information. In the example below you can see what we get when we write "GDP per capita".
# <br><br>

# %%
#Search available data series from the world bank
gdp_per_capita_data = wb.search("GDP per capita")
gdp_per_capita_data
# Out:
#                                id  \
# 691            6.0.GDPpc_constant
# 2410               CC.GHG.MEMG.GC
# 6388            FB.DPT.INSU.PC.ZS
# 10758           NV.AGR.PCAP.KD.ZG
# 10978              NY.GDP.PCAP.CD
# 10979              NY.GDP.PCAP.CN
# 10980              NY.GDP.PCAP.KD
# 10981           NY.GDP.PCAP.KD.ZG
# 10982              NY.GDP.PCAP.KN
# 10983           NY.GDP.PCAP.PP.CD
# 10984           NY.GDP.PCAP.PP.KD
# 10985        NY.GDP.PCAP.PP.KD.87
# 10986        NY.GDP.PCAP.PP.KD.ZG
# 11205              PER.ALL.PS.GDP
# 11282              PER.BAS.PS.GDP
# 11349               PER.JR.PS.GDP
# 11492               PER.PP.PS.GDP
# 11559              PER.PRM.PS.GDP
# 11653              PER.SEC.PS.GDP
# 11888               PER.SR.PS.GDP
# 11945              PER.TER.PS.GDP
# 11992               PER.TT.PS.GDP
# 12012              PER.VOC.PS.GDP
# 15668               SE.PRM.SATT.2
# 15732               SE.PRM.TATT.1
# 15965           SE.XPD.PRIM.PC.ZS
# 15969           SE.XPD.SECO.PC.ZS
# 15974           SE.XPD.TERT.PC.ZS
# 20239   UIS.XUNIT.GDPCAP.02.FSGOV
# 20240    UIS.XUNIT.GDPCAP.1.FSGOV
# 20241     UIS.XUNIT.GDPCAP.1.FSHH
# 20242    UIS.XUNIT.GDPCAP.2.FSGOV
# 20243   UIS.XUNIT.GDPCAP.23.FSGOV
# 20244    UIS.XUNIT.GDPCAP.23.FSHH
# 20245    UIS.XUNIT.GDPCAP.3.FSGOV
# 20246  UIS.XUNIT.GDPCAP.5T8.FSGOV
# 20247   UIS.XUNIT.GDPCAP.5T8.FSHH
#
#                                                     name unit  \
# 691    GDP per capita, PPP (constant 2011 internation...
# 2410   Macro drivers of GHG emissions growth in the p...
# 6388    Deposit insurance coverage (% of GDP per capita)
# 10758   Real agricultural GDP per capita growth rate (%)
# 10978                       GDP per capita (current US$)
# 10979                       GDP per capita (current LCU)
# 10980                 GDP per capita (constant 2015 US$)
# 10981                   GDP per capita growth (annual %)
# 10982                      GDP per capita (constant LCU)
# 10983      GDP per capita, PPP (current international $)
# 10984  GDP per capita, PPP (constant 2017 internation...
# 10985  GDP per capita, PPP (constant 1987 internation...
# 10986              GDP per capita, PPP annual growth (%)
# 11205  World Bank: Public education expenditure per s...
# 11282  World Bank: Public education expenditure per s...
# 11349  World Bank: Public education expenditure per s...
# 11492  World Bank: Public education expenditure per s...
# 11559  World Bank: Public education expenditure per s...
# 11653  World Bank: Public education expenditure per s...
# 11888  World Bank: Public education expenditure per s...
# 11945  World Bank: Public education expenditure per s...
# 11992  World Bank: Public education expenditure per s...
# 12012  World Bank: Public education expenditure per s...
# 15668  (De Facto) Average principal salary as percent...
# 15732  (De Jure) Average starting public-school teach...
# 15965  Government expenditure per student, primary (%...
# 15969  Government expenditure per student, secondary ...
# 15974  Government expenditure per student, tertiary (...
# 20239  Initial government funding per pre-primary stu...
# 20240  Initial government funding per primary student...
# 20241  Initial household funding per primary student ...
# 20242  Initial government funding per lower secondary...
# 20243  Initial government funding per secondary stude...
# 20244  Initial household funding per secondary studen...
# 20245  Initial government funding per upper secondary...
# 20246  Initial government funding per tertiary studen...
# 20247  Initial household funding per tertiary student...
#
#                                               source  \
# 691                                   LAC Equity Lab
# 2410   Country Climate and Development Report (CCDR)
# 6388                           WDI Database Archives
# 10758                  Africa Development Indicators
# 10978                   World Development Indicators
# 10979                   World Development Indicators
# 10980                   World Development Indicators
# 10981                   World Development Indicators
# 10982                   World Development Indicators
# 10983                   World Development Indicators
# 10984                   World Development Indicators
# 10985                          WDI Database Archives
# 10986                  Africa Development Indicators
# 11205                           Education Statistics
# 11282                           Education Statistics
# 11349                           Education Statistics
# 11492                           Education Statistics
# 11559                           Education Statistics
# 11653                           Education Statistics
# 11888                           Education Statistics
# 11945                           Education Statistics
# 11992                           Education Statistics
# 12012                           Education Statistics
# 15668                           Education Statistics
# 15732                           Education Statistics
# 15965                   World Development Indicators
# 15969                   World Development Indicators
# 15974                   World Development Indicators
# 20239                           Education Statistics
# 20240                           Education Statistics
# 20241                           Education Statistics
# 20242                           Education Statistics
# 20243                           Education Statistics
# 20244                           Education Statistics
# 20245                           Education Statistics
# 20246                           Education Statistics
# 20247                           Education Statistics
#
#                                               sourceNote  \
# 691    GDP per capita based on purchasing power parit...
# 2410   Data reflects the impact of GDP-per capita (as...
# 6388
# 10758  The growth rate of real per capita GDP in agri...
# 10978  GDP per capita is gross domestic product divid...
# 10979  GDP per capita is gross domestic product divid...
# 10980  GDP per capita is gross domestic product divid...
# 10981  Annual percentage growth rate of GDP per capit...
# 10982  GDP per capita is gross domestic product divid...
# 10983  This indicator provides per capita values for ...
# 10984  GDP per capita based on purchasing power parit...
# 10985
# 10986  Annual percentage growth rate of GDP per capit...
# 11205
# 11282
# 11349
# 11492
# 11559
# 11653
# 11888
# 11945
# 11992
# 12012
# 15668
# 15732
# 15965  Government expenditure per student is the aver...
# 15969  Government expenditure per student is the aver...
# 15974  Government expenditure per student is the aver...
# 20239  Total general (local, regional and central, cu...
# 20240  Total general (local, regional and central, cu...
# 20241  Total payments of households (pupils, students...
# 20242  Total general (local, regional and central, cu...
# 20243  Total general (local, regional and central, cu...
# 20244  Total payments of households (pupils, students...
# 20245  Total general (local, regional and central, cu...
# 20246  Total general (local, regional and central, cu...
# 20247  Total payments of households (pupils, students...
#
#                                       sourceOrganization            topics
# 691         b'World Development Indicators (World Bank)'  Economy & Growth
# 2410   b'Climate Watch. 2020. Washington, DC: World R...
# 6388                                                 b''
# 10758                  b'World Bank country economists.'
# 10978  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10979  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10980  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10981  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10982  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10983  b'International Comparison Program, World Bank...  Economy & Growth
# 10984  b'International Comparison Program, World Bank...  Economy & Growth
# 10985                                                b''
# 10986  b'"World Bank, International Comparison Progra...
# 11205                                                b''
# 11282                                                b''
# 11349                                                b''
# 11492                                                b''
# 11559                                                b''
# 11653                                                b''
# 11888                                                b''
# 11945                                                b''
# 11992                                                b''
# 12012                                                b''
# 15668   b'World Bank, Global Education Policy Dashboard'
# 15732   b'World Bank, Global Education Policy Dashboard'
# 15965  b'UNESCO Institute for Statistics (http://uis....        Education
# 15969  b'UNESCO Institute for Statistics (http://uis....        Education
# 15974  b'UNESCO Institute for Statistics (http://uis....        Education
# 20239                 b'UNESCO Institute for Statistics'
# 20240                 b'UNESCO Institute for Statistics'
# 20241                 b'UNESCO Institute for Statistics'
# 20242                 b'UNESCO Institute for Statistics'
# 20243                 b'UNESCO Institute for Statistics'
# 20244                 b'UNESCO Institute for Statistics'
# 20245                 b'UNESCO Institute for Statistics'
# 20246                 b'UNESCO Institute for Statistics'
# 20247                 b'UNESCO Institute for Statistics'

# %% [markdown]
# ## **Download history for an specific indicator**
#
# <font size="3"> As you can see in the table above, there are a lot of different indicators related with GDP per Capita. We can choose the one that reads "GDP per capita (current US$)", which is measured in actual dollar terms. If you look in the column id, you will find that the indicator is "NY.GDP.PCAP.CD". Let's use that id to get a time series of this information.
# <br><br>

# %%
my_indicator = 'NY.GDP.PCAP.CD'
my_indicator_history1 = wb.download(indicator = my_indicator)
my_indicator_history1
# Out:
#                     NY.GDP.PCAP.CD
# country       year
# Canada        2005    36382.507916
#               2004    32143.681408
#               2003    28300.463096
# Mexico        2005     8702.114481
#               2004     7883.523191
#               2003     7473.932375
# United States 2005    44123.407068
#               2004    41724.631629
#               2003    39490.274956

# %% [markdown]
# ## **Download history for an specific indicator for a time period**
#
# <font size="3"> You can specify which time period you would like to download as it is shown below.
# <br><br>

# %%
#DATES
start_date = datetime.datetime(2013, 12, 31)
end_date = datetime.datetime(2023, 12, 31)

my_indicator_history2 = wb.download(indicator = my_indicator, start=start_date,end=end_date)
my_indicator_history2
# Out:
#                     NY.GDP.PCAP.CD
# country       year
# Canada        2022    54917.662523
#               2021    52358.621641
#               2020    43349.677856
#               2019    46374.152752
#               2018    46548.638411
#               2017    45129.429298
#               2016    42315.603706
#               2015    43596.135537
#               2014    50955.998323
#               2013    52635.174958
# Mexico        2022    11496.522872
#               2021    10359.149863
#               2020     8894.890650
#               2019    10434.578365
#               2018    10130.320698
#               2017     9693.330091
#               2016     9152.737223
#               2015    10098.173181
#               2014    11490.021690
#               2013    11317.491061
# United States 2022    76329.582265
#               2021    70219.472454
#               2020    63528.634303
#               2019    65120.394663
#               2018    62823.309438
#               2017    59907.754261
#               2016    57866.744934
#               2015    56762.729452
#               2014    55123.849787
#               2013    53291.127689

# %% [markdown]
# ## **Download history for an specific indicator and specific country for a time period**
#
# <font size="3"> You can also specify a particular country using the following script.
# <br><br>

# %%
my_indicator_history3 = wb.download(indicator = my_indicator, start=start_date,end=end_date, country = 'BR')
my_indicator_history3
# Out:
#               NY.GDP.PCAP.CD
# country year
# Brazil  2022     8917.674911
#         2021     7696.784830
#         2020     6923.699912
#         2019     8845.324149
#         2018     9121.020995
#         2017     9896.718895
#         2016     8680.736469
#         2015     8783.215424
#         2014    12071.404464
#         2013    12258.565709

# %% [markdown]
# ## **Download history for an specific indicator and specific countries for a time period**
#
# <font size="3"> You can even do that for multiple countries as shown below.
# <br><br>

# %%
my_indicator_history4 = wb.download(indicator = my_indicator, start=start_date,end=end_date, country = ['BR','MX','CL'])
my_indicator_history4
# Out:
#               NY.GDP.PCAP.CD
# country year
# Brazil  2022     8917.674911
#         2021     7696.784830
#         2020     6923.699912
#         2019     8845.324149
#         2018     9121.020995
#         2017     9896.718895
#         2016     8680.736469
#         2015     8783.215424
#         2014    12071.404464
#         2013    12258.565709
# Chile   2022    15355.479740
#         2021    16240.607776
#         2020    13173.784794
#         2019    14632.690308
#         2018    15820.033357
#         2017    15034.058425
#         2016    13788.240016
#         2015    13567.357217
#         2014    14675.150873
#         2013    15842.159157
# Mexico  2022    11496.522872
#         2021    10359.149863
#         2020     8894.890650
#         2019    10434.578365
#         2018    10130.320698
#         2017     9693.330091
#         2016     9152.737223
#         2015    10098.173181
#         2014    11490.021690
#         2013    11317.491061

# %% [markdown]
# If this content is helpful and you want to make a donation please click on the button
#
# [![paypal](https://www.paypalobjects.com/en_US/i/btn/btn_donateCC_LG.gif)](https://www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&hosted_button_id=29CVY97MEQ9BY)
